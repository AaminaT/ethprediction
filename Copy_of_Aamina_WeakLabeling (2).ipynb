# %%
from google.colab import drive
# import os
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# for the time being will
# blocks = conn.execute("select * from blocks_").fetch_df()

import pandas as pd
import glob
import os
from pathlib import Path

df_dir = Path('/content/drive/MyDrive/Unzipped_Data')
info_paths = list(df_dir.rglob('*_Block/*Block_Info.csv'))
print(f'Found {len(info_paths)} files:')
for p in info_paths:
    print('  ', p.relative_to(df_dir))

dfs = []
for p in info_paths:
    try:
        dfs.append(pd.read_csv(p, low_memory=False))
    except Exception as e:
        print(f"Couldn’t read {p.name}: {e}")

df_info = pd.concat(dfs, ignore_index=True)
print("Combined shape:", df_info.shape)
# Out:
# Found 21 files:
#    17000000to17249999_Block/17000000to17249999_Block_Info.csv
#    17250000to17499999_Block/17250000to17499999_Block_Info.csv
#    17500000to17749999_Block/17500000to17749999_Block_Info.csv
#    17750000to17999999_Block/17750000to17999999_Block_Info.csv
#    18000000to18249999_Block/18000000to18249999_Block_Info.csv
#    18250000to18499999_Block/18250000to18499999_Block_Info.csv
#    18500000to18749999_Block/18500000to18749999_Block_Info.csv
#    18750000to18999999_Block/18750000to18999999_Block_Info.csv
#    19000000to19249999_Block/19000000to19249999_Block_Info.csv
#    19250000to19499999_Block/19250000to19499999_Block_Info.csv
#    19500000to19749999_Block/19500000to19749999_Block_Info.csv
#    19750000to19999999_Block/19750000to19999999_Block_Info.csv
#    20000000to20249999_Block/20000000to20249999_Block_Info.csv
#    20250000to20499999_Block/20250000to20499999_Block_Info.csv
#    20500000to20749999_Block/20500000to20749999_Block_Info.csv
#    20750000to20999999_Block/20750000to20999999_Block_Info.csv
#    21000000to21249999_Block/21000000to21249999_Block_Info.csv
#    21250000to21499999_Block/21250000to21499999_Block_Info.csv
#    21500000to21749999_Block/21500000to21749999_Block_Info.csv
#    21750000to21999999_Block/21750000to21999999_Block_Info.csv
#    22000000to22249999_Block/22000000to22249999_Block_Info.csv
# Combined shape: (5250000, 25)

# %%
cols_to_drop = [
    'difficulty',
    'blobGasUsed',
    'excessBlobGas',
    'blobBaseFeePerGas',
    'blobTxCnt',
    'blobCnt',
]

df_info.drop(columns=cols_to_drop, errors='ignore', inplace=True)
df_info["Date"] = pd.to_datetime(df_info["timestamp"], unit='s').dt.date
display(df_info.tail())
# Out:
#          blockNumber   timestamp   size  transactionCount  \
# 5249995     22249995  1744426211  64177               114
# 5249996     22249996  1744426223  25444                67
# 5249997     22249997  1744426235  73860               171
# 5249998     22249998  1744426247  99608               215
# 5249999     22249999  1744426259  82230               155
#
#          internalTxCntSimple  internalTxCntAdvanced  erc20TxCnt  erc721TxCnt  \
# 5249995                  186                   1714         211            3
# 5249996                   53                    327          53            0
# 5249997                  182                   1493         189            2
# 5249998                   80                   1144         255            8
# 5249999                   97                   1114         198            2
#
#                                        minerAddress  \
# 5249995  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 5249996  0x388c818ca8b9251b393131c08a736a67ccb19297
# 5249997  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 5249998  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 5249999  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
#
#                                                 minerExtra  gasLimit  \
# 5249995  0x546974616e2028746974616e6275696c6465722e7879...  35999965
# 5249996  0xd883010e0d846765746888676f312e32332e33856c69...  36000000
# 5249997                   0x6265617665726275696c642e6f7267  36000000
# 5249998  0x546974616e2028746974616e6275696c6465722e7879...  36000000
# 5249999  0x546974616e2028746974616e6275696c6465722e7879...  36000000
#
#           gasUsed  minGasPrice   maxGasPrice   avgGasPrice  \
# 5249995  35987931  400715498.0  3.000000e+10  1.852140e+09
# 5249996   6090474  451771450.0  5.045077e+10  4.900695e+09
# 5249997  33115873  413490379.0  3.000000e+10  1.350271e+09
# 5249998  20333657  456895018.0  2.359429e+10  1.579519e+09
# 5249999  17191235  464299436.0  7.090022e+11  1.094666e+10
#
#                      txFees  baseFeePerGas          burntFees  \
# 5249995   29781105670189702      400715498  14420921692654638
# 5249996   17900349650728486      450771450   2745411796167300
# 5249997   29811202857577221      413490379  13693094877685867
# 5249998   25740946872725060      456895018   9290346581020826
# 5249999  193726900615047452      464299436   7981880714643460
#
#                    tipsFees        Date
# 5249995   15360183977535064  2025-04-12
# 5249996   15154937854561186  2025-04-12
# 5249997   16118107979891354  2025-04-12
# 5249998   16450600291704234  2025-04-12
# 5249999  185745019900403992  2025-04-12

# %%
display(df_info[df_info["blockNumber"] == 17000000])
# Out:
#    blockNumber   timestamp   size  transactionCount  internalTxCntSimple  \
# 0     17000000  1680911891  52739               102                   61
#
#    internalTxCntAdvanced  erc20TxCnt  erc721TxCnt  \
# 0                    411          93           19
#
#                                  minerAddress  \
# 0  0x690b9a9e9aa1c9db991c7721a92d351db4fac990
#
#                          minerExtra  gasLimit  gasUsed   minGasPrice  \
# 0  0x627920406275696c64657230783639  30000000  9160778  2.058274e+10
#
#     maxGasPrice   avgGasPrice              txFees  baseFeePerGas  \
# 0  1.875432e+11  2.404440e+10  220872919006082422    20582738913
#
#             burntFees           tipsFees        Date
# 0  188553901813954314  32319017192128108  2023-04-07

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/ETH_USD_sep2022.csv' # the second last day is all NaN, please clean it out
eth_price= pd.read_csv(file_path)
eth_price.head()
# conn.register('eth_price', eth_price)
# conn.execute("create or replace table eth_price as select * from eth_price")
# Out:
#          Date         Open         High          Low        Close  \
# 0  2022-09-12  1762.084839  1778.163452  1698.293457  1713.765259
# 1  2022-09-13  1713.962524  1745.779053  1564.031860  1580.787964
# 2  2022-09-14  1574.858154  1642.157227  1564.031860  1634.755005
# 3  2022-09-15  1635.083008  1648.945679  1466.139404  1471.693481
# 4  2022-09-16  1471.928345  1480.564209  1415.581299  1432.447754
#
#      Adj Close       Volume
# 0  1713.765259  17688391310
# 1  1580.787964  23066821734
# 2  1634.755005  17897150206
# 3  1471.693481  26946275878
# 4  1432.447754  16764804299

# %%
df_info['Date']     = pd.to_datetime(df_info['Date'], errors='coerce')
eth_price['Date']   = pd.to_datetime(eth_price['Date'], errors='coerce')

df_info['Date']     = df_info['Date'].dt.normalize()
eth_price['Date']   = eth_price['Date'].dt.normalize()

# %%
merged = df_info.merge(
    eth_price,
    on = "Date", # 2024-05-20 TO 2025-04-12, POS SEPTEMBER 15TH 2022
    how = "inner"
)

# %%
merged
# Out:
#          blockNumber   timestamp   size  transactionCount  \
# 0           17000000  1680911891  52739               102
# 1           17000001  1680911903  66580               116
# 2           17000002  1680911915  52783                61
# 3           17000003  1680911927  64651               118
# 4           17000004  1680911939  42665                97
# ...              ...         ...    ...               ...
# 5249995     22249995  1744426211  64177               114
# 5249996     22249996  1744426223  25444                67
# 5249997     22249997  1744426235  73860               171
# 5249998     22249998  1744426247  99608               215
# 5249999     22249999  1744426259  82230               155
#
#          internalTxCntSimple  internalTxCntAdvanced  erc20TxCnt  erc721TxCnt  \
# 0                         61                    411          93           19
# 1                         41                    353          84           10
# 2                        206                   1298          78           12
# 3                         42                    400          92           11
# 4                         40                    220          46           21
# ...                      ...                    ...         ...          ...
# 5249995                  186                   1714         211            3
# 5249996                   53                    327          53            0
# 5249997                  182                   1493         189            2
# 5249998                   80                   1144         255            8
# 5249999                   97                   1114         198            2
#
#                                        minerAddress  \
# 0        0x690b9a9e9aa1c9db991c7721a92d351db4fac990
# 1        0xbaf6dc2e647aeb6f510f9e318856a1bcd66c5e19
# 2        0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 3        0x602b2c72a89a1c80dba2198c9dc472012c733e89
# 4        0x1f9090aae28b8a3dceadf281b0f12828e676c326
# ...                                             ...
# 5249995  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 5249996  0x388c818ca8b9251b393131c08a736a67ccb19297
# 5249997  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# 5249998  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 5249999  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
#
#                                                 minerExtra  ...  \
# 0                         0x627920406275696c64657230783639  ...
# 1        0x4d616465206f6e20746865206d6f6f6e20627920426c...  ...
# 2                                             0x546974616e  ...
# 3                           0x6279206275696c64657230783639  ...
# 4                     0x7273796e632d6275696c6465722e78797a  ...
# ...                                                    ...  ...
# 5249995  0x546974616e2028746974616e6275696c6465722e7879...  ...
# 5249996  0xd883010e0d846765746888676f312e32332e33856c69...  ...
# 5249997                   0x6265617665726275696c642e6f7267  ...
# 5249998  0x546974616e2028746974616e6275696c6465722e7879...  ...
# 5249999  0x546974616e2028746974616e6275696c6465722e7879...  ...
#
#          baseFeePerGas           burntFees            tipsFees       Date  \
# 0          20582738913  188553901813954314   32319017192128108 2023-04-07
# 1          19581179064  183851116938232200   16148497891862781 2023-04-07
# 2          18665624323  559853040150446046   14003671019846814 2023-04-07
# 3          20997863283  238181996890014582    6491608213185120 2023-04-07
# 4          20357980347  156512763647146410   16317950788091914 2023-04-07
# ...                ...                 ...                 ...        ...
# 5249995      400715498   14420921692654638   15360183977535064 2025-04-12
# 5249996      450771450    2745411796167300   15154937854561186 2025-04-12
# 5249997      413490379   13693094877685867   16118107979891354 2025-04-12
# 5249998      456895018    9290346581020826   16450600291704234 2025-04-12
# 5249999      464299436    7981880714643460  185745019900403992 2025-04-12
#
#                 Open         High          Low        Close    Adj Close  \
# 0        1872.734131  1882.299194  1845.993896  1865.636108  1865.636108
# 1        1872.734131  1882.299194  1845.993896  1865.636108  1865.636108
# 2        1872.734131  1882.299194  1845.993896  1865.636108  1865.636108
# 3        1872.734131  1882.299194  1845.993896  1865.636108  1865.636108
# 4        1872.734131  1882.299194  1845.993896  1865.636108  1865.636108
# ...              ...          ...          ...          ...          ...
# 5249995  1567.155762  1666.017578  1546.819580  1643.528564  1643.528564
# 5249996  1567.155762  1666.017578  1546.819580  1643.528564  1643.528564
# 5249997  1567.155762  1666.017578  1546.819580  1643.528564  1643.528564
# 5249998  1567.155762  1666.017578  1546.819580  1643.528564  1643.528564
# 5249999  1567.155762  1666.017578  1546.819580  1643.528564  1643.528564
#
#               Volume
# 0         8356130492
# 1         8356130492
# 2         8356130492
# 3         8356130492
# 4         8356130492
# ...              ...
# 5249995  12110995013
# 5249996  12110995013
# 5249997  12110995013
# 5249998  12110995013
# 5249999  12110995013
#
# [5250000 rows x 26 columns]

# %%
print(merged.dtypes)
# Out:
# blockNumber                       int64
# timestamp                         int64
# size                              int64
# transactionCount                  int64
# internalTxCntSimple               int64
# internalTxCntAdvanced             int64
# erc20TxCnt                        int64
# erc721TxCnt                       int64
# minerAddress                     object
# minerExtra                       object
# gasLimit                          int64
# gasUsed                           int64
# minGasPrice                     float64
# maxGasPrice                     float64
# avgGasPrice                     float64
# txFees                           object
# baseFeePerGas                     int64
# burntFees                        object
# tipsFees                         object
# Date                     datetime64[ns]
# Open                            float64
# High                            float64
# Low                             float64
# Close                           float64
# Adj Close                       float64
# Volume                            int64
# dtype: object

# %%
print(eth_price[['Open',	'High',	'Low',	'Close',	'Adj Close',	'Volume']].describe(percentiles=[.25, .5, .75]) )
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   982.000000   982.000000   982.000000   982.000000   982.000000
# mean   2292.726546  2344.709859  2237.533959  2293.489125  2293.489125
# std     764.340813   786.264467   738.807928   764.230175   764.230175
# min    1100.107178  1136.442627  1081.138184  1100.169800  1100.169800
# 25%    1663.779877  1692.379333  1636.019012  1663.482178  1663.482178
# 50%    2058.958496  2095.307129  2004.158997  2061.309570  2061.309570
# 75%    2940.545227  3012.086487  2864.437988  2940.027832  2940.027832
# max    4066.690430  4106.955566  3974.176270  4066.445068  4066.445068
#
#              Volume
# count  9.820000e+02
# mean   1.440279e+10
# std    1.059310e+10
# min    2.081626e+09
# 25%    7.187574e+09
# 50%    1.153363e+10
# 75%    1.790464e+10
# max    9.245355e+10

# %%
print( merged[['size', 'gasLimit', 'gasUsed', 'minGasPrice', 'maxGasPrice', 'avgGasPrice','txFees','baseFeePerGas','burntFees', 'tipsFees', 'transactionCount']].describe(percentiles=[.25, .5, .75]) )
# Out:
#                size      gasLimit       gasUsed   minGasPrice   maxGasPrice  \
# count  5.250000e+06  5.250000e+06  5.250000e+06  5.246737e+06  5.246737e+06
# mean   1.140609e+05  3.054562e+07  1.541771e+07  1.924039e+10  2.522663e+11
# std    1.040432e+05  1.709177e+06  6.127393e+06  2.148307e+10  6.353599e+12
# min    5.440000e+02  2.988296e+07  0.000000e+00  2.261364e+08  3.155464e+08
# 25%    5.762300e+04  3.000000e+07  1.157581e+07  5.289518e+09  4.187946e+10
# 50%    7.939400e+04  3.000000e+07  1.429089e+07  1.333743e+10  8.255203e+10
# 75%    1.418680e+05  3.000000e+07  1.806794e+07  2.615222e+10  1.812290e+11
# max    2.333167e+06  3.607034e+07  3.603448e+07  1.434392e+12  1.373127e+16
#
#         avgGasPrice  baseFeePerGas  transactionCount
# count  5.246737e+06   5.250000e+06      5.250000e+06
# mean   2.397270e+10   1.922234e+10      1.591432e+02
# std    1.687356e+11   2.146122e+10      6.410531e+01
# min    3.442325e+08   2.261364e+08      0.000000e+00
# 25%    7.795325e+09   5.269621e+09      1.240000e+02
# 50%    1.684976e+10   1.332509e+10      1.490000e+02
# 75%    3.127889e+10   2.613590e+10      1.820000e+02
# max    3.661806e+14   8.255167e+11      1.516000e+03

# %%
for col in ['Open','High','Low','Close', 'Adj Close', 'Volume']:
  idx = merged[col].idxmax()
  print(f"Max {col:5s} = {merged.loc[idx, col]:.2f} on {merged.loc[idx,'Date']} , Blockchain Details: BaseFeePerGas {merged.loc[idx,'baseFeePerGas']}, Burn Fees {merged.loc[idx,'burntFees']}, tx Fees {merged.loc[idx,'txFees']} ,  Size {merged.loc[idx,'size']} ,TransactionCount {merged.loc[idx,'transactionCount']}, blockNumber {merged.loc[idx,'blockNumber']} ")


print("\n")

for col in ['Open','High','Low','Close', 'Adj Close', 'Volume']:
    idx = merged[col].idxmin()
    print(f"Min {col:5s} = {merged.loc[idx, col]:.2f} on {merged.loc[idx,'Date']} , Blockchain Details: BaseFeePerGas {merged.loc[idx,'baseFeePerGas']}, Burn Fees {merged.loc[idx,'burntFees']}, Tx Fees {merged.loc[idx,'txFees']} ,  Size {merged.loc[idx,'size']} ,TransactionCount {merged.loc[idx,'transactionCount']}, blockNumber {merged.loc[idx,'blockNumber']} ")

print("\n")


price_cols = ['Open','High','Low','Close','Adj Close','Volume']

# Compute the raw stats
stats = {}
for col in price_cols:
    stats[col] = {
        'mean':   merged[col].mean(),
        'median': merged[col].median(),
        'q25':    merged[col].quantile(0.25),
        'q75':    merged[col].quantile(0.75),
    }

def nearest_k_idxs(series: pd.Series, target: float, k: int):
    """
    Return the Index labels of the k values in series
    whose absolute difference from target is smallest.
    """
    diffs = (series - target).abs()
    # .nsmallest returns a Series of length k, with the same index labels
    return diffs.nsmallest(k).index

# how many “nearest” you want
K = 10000

for col in price_cols:
    print(f"\n=== {col} ===")
    for stat_name, stat_val in stats[col].items():
        idxs = nearest_k_idxs(merged[col], stat_val, K)
        print(f"\n  {stat_name.capitalize():6s} ≈ {stat_val:,.2f} → nearest {K} days:")
        for idx in idxs:
            row = merged.loc[idx]
            print(
                f" on{row['Date'].date()}  "
                f"{col}={row[col]:.2f}  "
                f"BaseFeePerGas={row['baseFeePerGas']:.2f}, "
                f"gasUsed={row['gasUsed']:.2f}, "
                f"burntFees={row['burntFees']:.2f}, "
                f"size={int(row['size'])}, "
                f"txCount={int(row['transactionCount'])}, "
                f"blockNumber={int(row['blockNumber'])}"
            )
# Out:
# Streaming output truncated to the last 5000 lines.
#  on2024-08-31  Low=2493.71  BaseFeePerGas=616165638.00, gasUsed=14149695.00, burntFees=8718555847180410.00, size=76341, txCount=162, blockNumber=20646994
#  on2024-08-31  Low=2493.71  BaseFeePerGas=611799566.00, gasUsed=15152645.00, burntFees=9270381634752070.00, size=63852, txCount=134, blockNumber=20646995
#  on2024-08-31  Low=2493.71  BaseFeePerGas=612577800.00, gasUsed=12097788.00, burntFees=7410836357906400.00, size=61710, txCount=126, blockNumber=20646996
#  on2024-08-31  Low=2493.71  BaseFeePerGas=597762545.00, gasUsed=15537152.00, burntFees=9287527521571840.00, size=48412, txCount=97, blockNumber=20646997
#  on2024-08-31  Low=2493.71  BaseFeePerGas=600438289.00, gasUsed=7908610.00, burntFees=4748632256768290.00, size=37020, txCount=99, blockNumber=20646998
#  on2024-08-31  Low=2493.71  BaseFeePerGas=564955439.00, gasUsed=23947054.00, burntFees=13529018405326706.00, size=42963, txCount=87, blockNumber=20646999
#  on2024-08-31  Low=2493.71  BaseFeePerGas=607077829.00, gasUsed=19164034.00, burntFees=11634060155602186.00, size=91091, txCount=204, blockNumber=20647000
#  on2024-08-31  Low=2493.71  BaseFeePerGas=628143601.00, gasUsed=8130276.00, burntFees=5106980843763876.00, size=49310, txCount=105, blockNumber=20647001
#  on2024-08-31  Low=2493.71  BaseFeePerGas=592183825.00, gasUsed=26478711.00, burntFees=15680264361049576.00, size=62865, txCount=108, blockNumber=20647002
#  on2024-08-31  Low=2493.71  BaseFeePerGas=648829716.00, gasUsed=9261856.00, burntFees=6009367398112896.00, size=45281, txCount=114, blockNumber=20647003
#  on2024-08-31  Low=2493.71  BaseFeePerGas=617804064.00, gasUsed=15508208.00, burntFees=9581033927757312.00, size=77325, txCount=157, blockNumber=20647004
#  on2024-08-31  Low=2493.71  BaseFeePerGas=620420505.00, gasUsed=29982270.00, burntFees=18601615094446352.00, size=53346, txCount=153, blockNumber=20647005
#  on2024-08-31  Low=2493.71  BaseFeePerGas=697881400.00, gasUsed=9560204.00, burntFees=6671888551805600.00, size=38902, txCount=123, blockNumber=20647006
#  on2024-08-31  Low=2493.71  BaseFeePerGas=666245297.00, gasUsed=9995662.00, burntFees=6659562797901614.00, size=53768, txCount=90, blockNumber=20647007
#  on2024-08-31  Low=2493.71  BaseFeePerGas=638460992.00, gasUsed=6765251.00, burntFees=4319348864588992.00, size=58474, txCount=83, blockNumber=20647008
#  on2024-08-31  Low=2493.71  BaseFeePerGas=594647942.00, gasUsed=29980996.00, burntFees=17828137570510232.00, size=90715, txCount=206, blockNumber=20647009
#  on2024-08-31  Low=2493.71  BaseFeePerGas=668884762.00, gasUsed=10686426.00, burntFees=7147987511640612.00, size=37809, txCount=101, blockNumber=20647010
#  on2024-08-31  Low=2493.71  BaseFeePerGas=644840730.00, gasUsed=14691133.00, burntFees=9473440928247090.00, size=71929, txCount=128, blockNumber=20647011
#  on2024-08-31  Low=2493.71  BaseFeePerGas=643180980.00, gasUsed=13949679.00, burntFees=8972168209905420.00, size=61767, txCount=147, blockNumber=20647012
#  on2024-08-31  Low=2493.71  BaseFeePerGas=637551426.00, gasUsed=12454310.00, burntFees=7940263100346060.00, size=61135, txCount=114, blockNumber=20647013
#  on2024-08-31  Low=2493.71  BaseFeePerGas=624026357.00, gasUsed=11946343.00, burntFees=7454832901762451.00, size=59746, txCount=108, blockNumber=20647014
#  on2024-08-31  Low=2493.71  BaseFeePerGas=608146670.00, gasUsed=18702489.00, burntFees=11373856406061630.00, size=133954, txCount=115, blockNumber=20647015
#  on2024-08-31  Low=2493.71  BaseFeePerGas=626910472.00, gasUsed=15510390.00, burntFees=9723625915804080.00, size=77694, txCount=147, blockNumber=20647016
#  on2024-08-31  Low=2493.71  BaseFeePerGas=629576878.00, gasUsed=12593767.00, burntFees=7928744510119426.00, size=54934, txCount=158, blockNumber=20647017
#  on2024-08-31  Low=2493.71  BaseFeePerGas=616952640.00, gasUsed=7083564.00, burntFees=4370223510408960.00, size=28867, txCount=93, blockNumber=20647018
#  on2024-08-31  Low=2493.71  BaseFeePerGas=576252090.00, gasUsed=25300129.00, burntFees=14579252213519610.00, size=56395, txCount=142, blockNumber=20647019
#  on2024-08-31  Low=2493.71  BaseFeePerGas=625714347.00, gasUsed=21735912.00, burntFees=13600471983529464.00, size=92581, txCount=186, blockNumber=20647020
#  on2024-08-31  Low=2493.71  BaseFeePerGas=660837320.00, gasUsed=12936531.00, burntFees=8548942476136920.00, size=56136, txCount=136, blockNumber=20647021
#  on2024-08-31  Low=2493.71  BaseFeePerGas=649473843.00, gasUsed=10366962.00, burntFees=6733070650374966.00, size=53239, txCount=136, blockNumber=20647022
#  on2024-08-31  Low=2493.71  BaseFeePerGas=624398535.00, gasUsed=21218511.00, burntFees=13248807183281384.00, size=60318, txCount=155, blockNumber=20647023
#  on2024-08-31  Low=2493.71  BaseFeePerGas=656755444.00, gasUsed=13464236.00, burntFees=8842710292300784.00, size=78194, txCount=106, blockNumber=20647024
#  on2024-08-31  Low=2493.71  BaseFeePerGas=648350266.00, gasUsed=9329893.00, burntFees=6049038608301538.00, size=45575, txCount=128, blockNumber=20647025
#  on2024-08-31  Low=2493.71  BaseFeePerGas=617715138.00, gasUsed=11950115.00, burntFees=7381766936340870.00, size=60210, txCount=150, blockNumber=20647026
#  on2024-08-31  Low=2493.71  BaseFeePerGas=602015471.00, gasUsed=14110835.00, burntFees=8494940978728285.00, size=55881, txCount=134, blockNumber=20647027
#  on2024-08-31  Low=2493.71  BaseFeePerGas=597554712.00, gasUsed=19326755.00, burntFees=11548793517919560.00, size=86396, txCount=166, blockNumber=20647028
#  on2024-08-31  Low=2493.71  BaseFeePerGas=619100318.00, gasUsed=11074795.00, burntFees=6856409106284810.00, size=60919, txCount=100, blockNumber=20647029
#  on2024-08-31  Low=2493.71  BaseFeePerGas=598849521.00, gasUsed=15363801.00, burntFees=9200604869589320.00, size=59958, txCount=151, blockNumber=20647030
#  on2024-08-31  Low=2493.71  BaseFeePerGas=600665038.00, gasUsed=11011123.00, burntFees=6613996615217674.00, size=26573, txCount=56, blockNumber=20647031
#  on2024-08-31  Low=2493.71  BaseFeePerGas=580698547.00, gasUsed=19697331.00, burntFees=11438211491478056.00, size=75024, txCount=169, blockNumber=20647032
#  on2024-08-31  Low=2493.71  BaseFeePerGas=603429657.00, gasUsed=23210115.00, burntFees=14005671733380556.00, size=60553, txCount=91, blockNumber=20647033
#  on2024-08-31  Low=2493.71  BaseFeePerGas=644714880.00, gasUsed=17668568.00, burntFees=11391188697891840.00, size=90312, txCount=186, blockNumber=20647034
#  on2024-08-31  Low=2493.71  BaseFeePerGas=659052092.00, gasUsed=8842357.00, burntFees=5827573879060844.00, size=44021, txCount=106, blockNumber=20647035
#  on2024-08-31  Low=2493.71  BaseFeePerGas=625233697.00, gasUsed=16016920.00, burntFees=10014318106153240.00, size=37694, txCount=98, blockNumber=20647036
#  on2024-08-31  Low=2493.71  BaseFeePerGas=630532135.00, gasUsed=22774283.00, burntFees=14359917283084204.00, size=96522, txCount=149, blockNumber=20647037
#  on2024-08-31  Low=2493.71  BaseFeePerGas=671381595.00, gasUsed=19900819.00, burntFees=13361043602026304.00, size=59905, txCount=113, blockNumber=20647038
#  on2024-08-31  Low=2493.71  BaseFeePerGas=698800925.00, gasUsed=7509321.00, burntFees=5247520460921925.00, size=37225, txCount=98, blockNumber=20647039
#  on2024-08-31  Low=2493.71  BaseFeePerGas=655180147.00, gasUsed=18255037.00, burntFees=11960337825150440.00, size=65556, txCount=172, blockNumber=20647040
#  on2024-08-31  Low=2493.71  BaseFeePerGas=672952110.00, gasUsed=18047148.00, burntFees=12144866326082280.00, size=53700, txCount=137, blockNumber=20647041
#  on2024-08-31  Low=2493.71  BaseFeePerGas=690040315.00, gasUsed=14453658.00, burntFees=9973606719222270.00, size=72135, txCount=141, blockNumber=20647042
#  on2024-08-31  Low=2493.71  BaseFeePerGas=686898665.00, gasUsed=21136238.00, burntFees=14518453665322270.00, size=47694, txCount=183, blockNumber=20647043
#  on2024-08-31  Low=2493.71  BaseFeePerGas=722023445.00, gasUsed=1797996.00, burntFees=1298195266016220.00, size=14686, txCount=24, blockNumber=20647044
#  on2024-08-31  Low=2493.71  BaseFeePerGas=642588809.00, gasUsed=28618875.00, burntFees=18390168801169876.00, size=90829, txCount=204, blockNumber=20647045
#  on2024-08-31  Low=2493.71  BaseFeePerGas=715516614.00, gasUsed=11647500.00, burntFees=8333979761565000.00, size=49779, txCount=110, blockNumber=20647046
#  on2024-08-31  Low=2493.71  BaseFeePerGas=695526869.00, gasUsed=8867012.00, burntFees=6167245093745428.00, size=36194, txCount=102, blockNumber=20647047
#  on2024-08-31  Low=2493.71  BaseFeePerGas=659979720.00, gasUsed=20433540.00, burntFees=13485722007808800.00, size=51241, txCount=144, blockNumber=20647048
#  on2024-08-31  Low=2493.71  BaseFeePerGas=689863271.00, gasUsed=10085915.00, burntFees=6957902312927965.00, size=45209, txCount=116, blockNumber=20647049
#  on2024-08-31  Low=2493.71  BaseFeePerGas=661612882.00, gasUsed=11026781.00, burntFees=7295460356592842.00, size=63273, txCount=85, blockNumber=20647050
#  on2024-08-31  Low=2493.71  BaseFeePerGas=639706775.00, gasUsed=27217092.00, burntFees=17410958148198300.00, size=97856, txCount=211, blockNumber=20647051
#  on2024-08-31  Low=2493.71  BaseFeePerGas=704834746.00, gasUsed=5356836.00, burntFees=3775684141423656.00, size=25377, txCount=66, blockNumber=20647052
#  on2024-08-31  Low=2493.71  BaseFeePerGas=648194438.00, gasUsed=18314502.00, burntFees=11871358331139876.00, size=81142, txCount=160, blockNumber=20647053
#  on2024-08-31  Low=2493.71  BaseFeePerGas=666098119.00, gasUsed=18901668.00, burntFees=12590365500762492.00, size=65780, txCount=119, blockNumber=20647054
#  on2024-08-31  Low=2493.71  BaseFeePerGas=687755566.00, gasUsed=15768607.00, burntFees=10844947232316562.00, size=43026, txCount=131, blockNumber=20647055
#  on2024-08-31  Low=2493.71  BaseFeePerGas=692160680.00, gasUsed=5363814.00, burntFees=3712621145633520.00, size=26931, txCount=75, blockNumber=20647056
#  on2024-08-31  Low=2493.71  BaseFeePerGas=636579105.00, gasUsed=24121822.00, burntFees=15355447859729310.00, size=110704, txCount=186, blockNumber=20647057
#  on2024-08-31  Low=2493.71  BaseFeePerGas=684968782.00, gasUsed=589596.00, burntFees=403854853992072.00, size=4277, txCount=15, blockNumber=20647058
#  on2024-08-31  Low=2493.71  BaseFeePerGas=602713142.00, gasUsed=29979490.00, burntFees=18069032613457580.00, size=113412, txCount=242, blockNumber=20647059
#  on2024-08-31  Low=2493.71  BaseFeePerGas=677949271.00, gasUsed=13110948.00, burntFees=8888557638718908.00, size=53438, txCount=101, blockNumber=20647060
#  on2024-08-31  Low=2493.71  BaseFeePerGas=667276926.00, gasUsed=13152896.00, burntFees=8776624010877696.00, size=56852, txCount=136, blockNumber=20647061
#  on2024-08-31  Low=2493.71  BaseFeePerGas=657005844.00, gasUsed=27460278.00, burntFees=18041563123864632.00, size=50095, txCount=110, blockNumber=20647062
#  on2024-08-31  Low=2493.71  BaseFeePerGas=725226472.00, gasUsed=8742151.00, burntFees=6340039327421272.00, size=29128, txCount=73, blockNumber=20647063
#  on2024-08-31  Low=2493.71  BaseFeePerGas=687406825.00, gasUsed=15663031.00, burntFees=10766874409586576.00, size=69006, txCount=177, blockNumber=20647064
#  on2024-08-31  Low=2493.71  BaseFeePerGas=691204925.00, gasUsed=13471404.00, burntFees=9311500791464700.00, size=33930, txCount=94, blockNumber=20647065
#  on2024-08-31  Low=2493.71  BaseFeePerGas=682400150.00, gasUsed=1142981.00, burntFees=779970405847150.00, size=6483, txCount=23, blockNumber=20647066
#  on2024-08-31  Low=2493.71  BaseFeePerGas=603599885.00, gasUsed=26117423.00, burntFees=15764473519296356.00, size=128483, txCount=290, blockNumber=20647067
#  on2024-08-31  Low=2493.71  BaseFeePerGas=659520512.00, gasUsed=15724078.00, burntFees=10370351973287936.00, size=43895, txCount=141, blockNumber=20647068
#  on2024-08-31  Low=2493.71  BaseFeePerGas=663500047.00, gasUsed=14956690.00, burntFees=9923764517964430.00, size=66673, txCount=198, blockNumber=20647069
#  on2024-08-31  Low=2493.71  BaseFeePerGas=663260579.00, gasUsed=17155839.00, burntFees=11378791708370780.00, size=49708, txCount=164, blockNumber=20647070
#  on2024-08-31  Low=2493.71  BaseFeePerGas=675176270.00, gasUsed=10854153.00, burntFees=7328466536549310.00, size=49485, txCount=113, blockNumber=20647071
#  on2024-08-31  Low=2493.71  BaseFeePerGas=651849791.00, gasUsed=12708351.00, burntFees=8283935943304641.00, size=58758, txCount=161, blockNumber=20647072
#  on2024-08-31  Low=2493.71  BaseFeePerGas=639401367.00, gasUsed=9459424.00, burntFees=6048368636632608.00, size=45373, txCount=118, blockNumber=20647073
#  on2024-08-31  Low=2493.71  BaseFeePerGas=609879269.00, gasUsed=9666068.00, burntFees=5895134485944292.00, size=45831, txCount=124, blockNumber=20647074
#  on2024-08-31  Low=2493.71  BaseFeePerGas=582770482.00, gasUsed=17574229.00, burntFees=10241741905108378.00, size=46382, txCount=108, blockNumber=20647075
#  on2024-08-31  Low=2493.71  BaseFeePerGas=595272020.00, gasUsed=29707291.00, burntFees=17683919122297820.00, size=70324, txCount=144, blockNumber=20647076
#  on2024-08-31  Low=2493.71  BaseFeePerGas=668229010.00, gasUsed=11811179.00, burntFees=7892572450102790.00, size=98735, txCount=83, blockNumber=20647077
#  on2024-08-31  Low=2493.71  BaseFeePerGas=650471821.00, gasUsed=20519124.00, burntFees=13347111953604804.00, size=46191, txCount=120, blockNumber=20647078
#  on2024-08-31  Low=2493.71  BaseFeePerGas=680388776.00, gasUsed=11415400.00, burntFees=7766910033550400.00, size=41366, txCount=112, blockNumber=20647079
#  on2024-08-31  Low=2493.71  BaseFeePerGas=660064430.00, gasUsed=29861371.00, burntFees=19710428828133528.00, size=98481, txCount=92, blockNumber=20647080
#  on2024-08-31  Low=2493.71  BaseFeePerGas=741809949.00, gasUsed=8818597.00, burntFees=6541722990821553.00, size=38312, txCount=81, blockNumber=20647081
#  on2024-08-31  Low=2493.71  BaseFeePerGas=703598064.00, gasUsed=8170573.00, burntFees=5748799344570672.00, size=31623, txCount=85, blockNumber=20647082
#  on2024-08-31  Low=2493.71  BaseFeePerGas=663554968.00, gasUsed=26147686.00, burntFees=17350426947004048.00, size=70593, txCount=167, blockNumber=20647083
#  on2024-08-31  Low=2493.71  BaseFeePerGas=725197488.00, gasUsed=12513581.00, burntFees=9074817507084528.00, size=51349, txCount=136, blockNumber=20647084
#  on2024-08-31  Low=2493.71  BaseFeePerGas=710171282.00, gasUsed=14685411.00, burntFees=10429157156566902.00, size=34291, txCount=99, blockNumber=20647085
#  on2024-08-31  Low=2493.71  BaseFeePerGas=708309515.00, gasUsed=7265992.00, burntFees=5146571269513880.00, size=33794, txCount=84, blockNumber=20647086
#  on2024-08-31  Low=2493.71  BaseFeePerGas=662658920.00, gasUsed=17810488.00, burntFees=11802278742752960.00, size=180363, txCount=119, blockNumber=20647087
#  on2024-08-31  Low=2493.71  BaseFeePerGas=678178877.00, gasUsed=14589668.00, burntFees=9894404660042836.00, size=38308, txCount=107, blockNumber=20647088
#  on2024-08-31  Low=2493.71  BaseFeePerGas=675859890.00, gasUsed=21116857.00, burntFees=14272036649165730.00, size=43269, txCount=111, blockNumber=20647089
#  on2024-08-31  Low=2493.71  BaseFeePerGas=710311042.00, gasUsed=13309341.00, burntFees=9453771874043322.00, size=46520, txCount=118, blockNumber=20647090
#  on2024-08-31  Low=2493.71  BaseFeePerGas=700303595.00, gasUsed=15606629.00, burntFees=10929378394531256.00, size=43373, txCount=117, blockNumber=20647091
#  on2024-08-31  Low=2493.71  BaseFeePerGas=703843798.00, gasUsed=12705715.00, burntFees=8942838701905570.00, size=59309, txCount=112, blockNumber=20647092
#  on2024-08-31  Low=2493.71  BaseFeePerGas=690386980.00, gasUsed=17767088.00, burntFees=12266166227714240.00, size=52441, txCount=110, blockNumber=20647093
#  on2024-08-31  Low=2493.71  BaseFeePerGas=706306659.00, gasUsed=11666179.00, burntFees=8239899912785961.00, size=48400, txCount=150, blockNumber=20647094
#  on2024-08-31  Low=2493.71  BaseFeePerGas=686684160.00, gasUsed=10905944.00, burntFees=7488938994647040.00, size=48935, txCount=98, blockNumber=20647095
#  on2024-08-31  Low=2493.71  BaseFeePerGas=663256465.00, gasUsed=29998511.00, burntFees=19896706361123616.00, size=58105, txCount=104, blockNumber=20647096
#  on2024-08-31  Low=2493.71  BaseFeePerGas=746155293.00, gasUsed=10077204.00, burntFees=7519159103240772.00, size=43907, txCount=134, blockNumber=20647097
#  on2024-08-31  Low=2493.71  BaseFeePerGas=715545541.00, gasUsed=11925337.00, burntFees=8533121715272317.00, size=41600, txCount=96, blockNumber=20647098
#  on2024-08-31  Low=2493.71  BaseFeePerGas=697211697.00, gasUsed=8058654.00, burntFees=5618587830875838.00, size=43732, txCount=157, blockNumber=20647099
#  on2024-08-31  Low=2493.71  BaseFeePerGas=656881801.00, gasUsed=14994727.00, burntFees=9849763277263328.00, size=60566, txCount=164, blockNumber=20647100
#  on2024-08-31  Low=2493.71  BaseFeePerGas=656852937.00, gasUsed=9341162.00, burntFees=6135769694692794.00, size=40408, txCount=134, blockNumber=20647101
#  on2024-08-31  Low=2493.71  BaseFeePerGas=625877734.00, gasUsed=18066664.00, burntFees=11307522725259376.00, size=93235, txCount=105, blockNumber=20647102
#  on2024-08-31  Low=2493.71  BaseFeePerGas=641872373.00, gasUsed=29984827.00, burntFees=19246432060484472.00, size=42788, txCount=68, blockNumber=20647103
#  on2024-08-31  Low=2493.71  BaseFeePerGas=722025260.00, gasUsed=12959963.00, burntFees=9357420654665380.00, size=74221, txCount=149, blockNumber=20647104
#  on2024-08-31  Low=2493.71  BaseFeePerGas=709750608.00, gasUsed=17965597.00, burntFees=12751093393832976.00, size=55427, txCount=121, blockNumber=20647105
#  on2024-08-31  Low=2493.71  BaseFeePerGas=727290893.00, gasUsed=15539200.00, burntFees=11301518644505600.00, size=59831, txCount=137, blockNumber=20647106
#  on2024-08-31  Low=2493.71  BaseFeePerGas=730558853.00, gasUsed=5035800.00, burntFees=3678948271937400.00, size=26193, txCount=69, blockNumber=20647107
#  on2024-08-31  Low=2493.71  BaseFeePerGas=669896899.00, gasUsed=7646569.00, burntFees=5122412861089531.00, size=31324, txCount=79, blockNumber=20647108
#  on2024-08-31  Low=2493.71  BaseFeePerGas=628846561.00, gasUsed=19517607.00, burntFees=12273580040899528.00, size=99638, txCount=194, blockNumber=20647109
#  on2024-08-31  Low=2493.71  BaseFeePerGas=652520574.00, gasUsed=29995412.00, burntFees=19572623455606488.00, size=39827, txCount=93, blockNumber=20647110
#  on2024-08-31  Low=2493.71  BaseFeePerGas=734060697.00, gasUsed=6719599.00, burntFees=4932593525500503.00, size=29488, txCount=83, blockNumber=20647111
#  on2024-08-31  Low=2493.71  BaseFeePerGas=683408056.00, gasUsed=12849438.00, burntFees=8781409444272528.00, size=64252, txCount=149, blockNumber=20647112
#  on2024-08-31  Low=2493.71  BaseFeePerGas=671160462.00, gasUsed=7949573.00, burntFees=5335439087382726.00, size=43698, txCount=91, blockNumber=20647113
#  on2024-08-31  Low=2493.71  BaseFeePerGas=631727397.00, gasUsed=9613431.00, burntFees=6073067741869107.00, size=46262, txCount=137, blockNumber=20647114
#  on2024-08-31  Low=2493.71  BaseFeePerGas=603370371.00, gasUsed=27853201.00, burntFees=16805796220907572.00, size=125688, txCount=306, blockNumber=20647115
#  on2024-08-31  Low=2493.71  BaseFeePerGas=667997376.00, gasUsed=11522410.00, burntFees=7696939645196160.00, size=49188, txCount=117, blockNumber=20647116
#  on2024-08-31  Low=2493.71  BaseFeePerGas=648638868.00, gasUsed=11996214.00, burntFees=7781210669245752.00, size=44441, txCount=138, blockNumber=20647117
#  on2024-08-31  Low=2493.71  BaseFeePerGas=632402432.00, gasUsed=29995766.00, burntFees=18969395368102912.00, size=38886, txCount=75, blockNumber=20647118
#  on2024-08-31  Low=2493.71  BaseFeePerGas=711430422.00, gasUsed=8619456.00, burntFees=6132143219490432.00, size=38731, txCount=105, blockNumber=20647119
#  on2024-08-31  Low=2493.71  BaseFeePerGas=673602813.00, gasUsed=5616255.00, burntFees=3783125166525315.00, size=32309, txCount=106, blockNumber=20647120
#  on2024-08-31  Low=2493.71  BaseFeePerGas=620928505.00, gasUsed=17569017.00, burntFees=10909103460129584.00, size=90313, txCount=223, blockNumber=20647121
#  on2024-08-31  Low=2493.71  BaseFeePerGas=634221637.00, gasUsed=29997573.00, burntFees=19025109854087000.00, size=29635, txCount=36, blockNumber=20647122
#  on2024-08-31  Low=2493.71  BaseFeePerGas=713486514.00, gasUsed=20615900.00, burntFees=14709166623972600.00, size=69048, txCount=172, blockNumber=20647123
#  on2024-08-31  Low=2493.71  BaseFeePerGas=746877088.00, gasUsed=10153350.00, burntFees=7583304481444800.00, size=45932, txCount=112, blockNumber=20647124
#  on2024-08-31  Low=2493.71  BaseFeePerGas=716711657.00, gasUsed=11923228.00, burntFees=8545516496668796.00, size=53053, txCount=133, blockNumber=20647125
#  on2024-08-31  Low=2493.71  BaseFeePerGas=698335338.00, gasUsed=3476778.00, burntFees=2427956939780964.00, size=19794, txCount=66, blockNumber=20647126
#  on2024-08-31  Low=2493.71  BaseFeePerGas=631276396.00, gasUsed=17388226.00, burntFees=10976776642113496.00, size=77192, txCount=175, blockNumber=20647127
#  on2024-08-31  Low=2493.71  BaseFeePerGas=643839985.00, gasUsed=12874830.00, burntFees=8289330354077550.00, size=52536, txCount=136, blockNumber=20647128
#  on2024-08-31  Low=2493.71  BaseFeePerGas=632437740.00, gasUsed=29999248.00, burntFees=18972656606819520.00, size=58034, txCount=147, blockNumber=20647129
#  on2024-08-31  Low=2493.71  BaseFeePerGas=711488494.00, gasUsed=8437854.00, burntFees=6003436035051876.00, size=40877, txCount=115, blockNumber=20647130
#  on2024-08-31  Low=2493.71  BaseFeePerGas=672581066.00, gasUsed=6846131.00, burntFees=4604578085955646.00, size=35217, txCount=99, blockNumber=20647131
#  on2024-08-31  Low=2493.71  BaseFeePerGas=626879917.00, gasUsed=13904458.00, burntFees=8716425476969986.00, size=109503, txCount=172, blockNumber=20647132
#  on2024-08-31  Low=2493.71  BaseFeePerGas=621156807.00, gasUsed=29995433.00, burntFees=18631867386862432.00, size=27615, txCount=80, blockNumber=20647133
#  on2024-08-31  Low=2493.71  BaseFeePerGas=698777767.00, gasUsed=15270383.00, burntFees=10670604133974760.00, size=47886, txCount=134, blockNumber=20647134
#  on2024-08-31  Low=2493.71  BaseFeePerGas=700352247.00, gasUsed=9256130.00, burntFees=6482551444024110.00, size=35837, txCount=108, blockNumber=20647135
#  on2024-08-31  Low=2493.71  BaseFeePerGas=666829479.00, gasUsed=9632059.00, burntFees=6422940884667261.00, size=43271, txCount=126, blockNumber=20647136
#  on2024-08-31  Low=2493.71  BaseFeePerGas=637000302.00, gasUsed=10041119.00, burntFees=6396195835417938.00, size=52088, txCount=105, blockNumber=20647137
#  on2024-08-31  Low=2493.71  BaseFeePerGas=610676897.00, gasUsed=23203568.00, burntFees=14169882905568496.00, size=86412, txCount=237, blockNumber=20647138
#  on2024-08-31  Low=2493.71  BaseFeePerGas=652424642.00, gasUsed=29984691.00, burntFees=19562751291155624.00, size=38220, txCount=95, blockNumber=20647139
#  on2024-08-31  Low=2493.71  BaseFeePerGas=733894489.00, gasUsed=5865174.00, burntFees=4304418875626086.00, size=23265, txCount=68, blockNumber=20647140
#  on2024-08-31  Low=2493.71  BaseFeePerGas=678027836.00, gasUsed=22964814.00, burntFees=15570783140562504.00, size=99992, txCount=400, blockNumber=20647141
#  on2024-08-31  Low=2493.71  BaseFeePerGas=723030882.00, gasUsed=6598654.00, burntFees=4771030621632828.00, size=29999, txCount=61, blockNumber=20647142
#  on2024-08-31  Low=2493.71  BaseFeePerGas=672410611.00, gasUsed=19279472.00, burntFees=12963721547277392.00, size=80058, txCount=234, blockNumber=20647143
#  on2024-08-31  Low=2493.71  BaseFeePerGas=696390297.00, gasUsed=18832255.00, burntFees=13114599652629736.00, size=69054, txCount=122, blockNumber=20647144
#  on2024-08-31  Low=2493.71  BaseFeePerGas=718629840.00, gasUsed=14724877.00, burntFees=10581736002529680.00, size=85398, txCount=152, blockNumber=20647145
#  on2024-08-31  Low=2493.71  BaseFeePerGas=716982244.00, gasUsed=11145107.00, burntFees=7990843826480108.00, size=47315, txCount=137, blockNumber=20647146
#  on2024-08-31  Low=2493.71  BaseFeePerGas=693949829.00, gasUsed=14938959.00, burntFees=10366888043488012.00, size=49633, txCount=113, blockNumber=20647147
#  on2024-08-31  Low=2493.71  BaseFeePerGas=693596835.00, gasUsed=19251725.00, burntFees=13352935528290376.00, size=74840, txCount=211, blockNumber=20647148
#  on2024-08-31  Low=2493.71  BaseFeePerGas=718171693.00, gasUsed=14016399.00, burntFees=10066180999593508.00, size=181591, txCount=155, blockNumber=20647149
#  on2024-08-31  Low=2493.71  BaseFeePerGas=712285074.00, gasUsed=20120382.00, burntFees=14331447781778268.00, size=64406, txCount=178, blockNumber=20647150
#  on2024-08-31  Low=2493.71  BaseFeePerGas=742678171.00, gasUsed=11036973.00, burntFees=8196918921016383.00, size=50575, txCount=112, blockNumber=20647151
#  on2024-08-31  Low=2493.71  BaseFeePerGas=718151058.00, gasUsed=17256152.00, burntFees=12392523815808816.00, size=87176, txCount=157, blockNumber=20647152
#  on2024-08-31  Low=2493.71  BaseFeePerGas=731653207.00, gasUsed=17702217.00, burntFees=12951883839059920.00, size=70215, txCount=161, blockNumber=20647153
#  on2024-08-31  Low=2493.71  BaseFeePerGas=748128921.00, gasUsed=18077803.00, burntFees=13524527252440564.00, size=52186, txCount=136, blockNumber=20647154
#  on2024-08-31  Low=2493.71  BaseFeePerGas=767317199.00, gasUsed=29513466.00, burntFees=22646190063901736.00, size=52433, txCount=140, blockNumber=20647155
#  on2024-08-31  Low=2493.71  BaseFeePerGas=860120799.00, gasUsed=11655974.00, burntFees=10025545670003226.00, size=72144, txCount=113, blockNumber=20647156
#  on2024-08-31  Low=2493.71  BaseFeePerGas=836151914.00, gasUsed=9015729.00, burntFees=7538519059455306.00, size=40137, txCount=114, blockNumber=20647157
#  on2024-08-31  Low=2493.71  BaseFeePerGas=794453917.00, gasUsed=18117429.00, burntFees=14393462435019392.00, size=81946, txCount=181, blockNumber=20647158
#  on2024-08-31  Low=2493.71  BaseFeePerGas=815092697.00, gasUsed=9958945.00, burntFees=8117463339324665.00, size=40605, txCount=150, blockNumber=20647159
#  on2024-08-31  Low=2493.71  BaseFeePerGas=780851638.00, gasUsed=24188142.00, burntFees=18887350300876596.00, size=83544, txCount=179, blockNumber=20647160
#  on2024-08-31  Low=2493.71  BaseFeePerGas=840639769.00, gasUsed=9654328.00, burntFees=8115812059770232.00, size=32940, txCount=90, blockNumber=20647161
#  on2024-08-31  Low=2493.71  BaseFeePerGas=803191566.00, gasUsed=13205080.00, burntFees=10606208884355280.00, size=58665, txCount=137, blockNumber=20647162
#  on2024-08-31  Low=2493.71  BaseFeePerGas=791177695.00, gasUsed=18027096.00, burntFees=14262636260823720.00, size=62425, txCount=139, blockNumber=20647163
#  on2024-08-31  Low=2493.71  BaseFeePerGas=811135785.00, gasUsed=11010493.00, burntFees=8931004882792005.00, size=42330, txCount=152, blockNumber=20647164
#  on2024-08-31  Low=2493.71  BaseFeePerGas=784168853.00, gasUsed=14040765.00, burntFees=11010330585292544.00, size=71340, txCount=181, blockNumber=20647165
#  on2024-08-31  Low=2493.71  BaseFeePerGas=777900502.00, gasUsed=17160780.00, burntFees=13349379376711560.00, size=53691, txCount=151, blockNumber=20647166
#  on2024-08-31  Low=2493.71  BaseFeePerGas=791907767.00, gasUsed=10086211.00, burntFees=7987348830500837.00, size=41726, txCount=106, blockNumber=20647167
#  on2024-08-31  Low=2493.71  BaseFeePerGas=759480537.00, gasUsed=7091842.00, burntFees=5386115970479154.00, size=24047, txCount=88, blockNumber=20647168
#  on2024-08-31  Low=2493.71  BaseFeePerGas=709429770.00, gasUsed=21613930.00, burntFees=15333565388696100.00, size=86142, txCount=210, blockNumber=20647169
#  on2024-08-31  Low=2493.71  BaseFeePerGas=748530760.00, gasUsed=14978604.00, burntFees=11211945835859040.00, size=78188, txCount=171, blockNumber=20647170
#  on2024-08-31  Low=2493.71  BaseFeePerGas=748397297.00, gasUsed=9946530.00, burntFees=7443956166529410.00, size=50479, txCount=121, blockNumber=20647171
#  on2024-08-31  Low=2493.71  BaseFeePerGas=716880603.00, gasUsed=12862314.00, burntFees=9220743416295342.00, size=55259, txCount=148, blockNumber=20647172
#  on2024-08-31  Low=2493.71  BaseFeePerGas=704110057.00, gasUsed=7583902.00, burntFees=5339901669502414.00, size=42195, txCount=79, blockNumber=20647173
#  on2024-08-31  Low=2493.71  BaseFeePerGas=660595481.00, gasUsed=27991383.00, burntFees=18490981116740224.00, size=130156, txCount=237, blockNumber=20647174
#  on2024-08-31  Low=2493.71  BaseFeePerGas=732112555.00, gasUsed=13816351.00, burntFees=10115124031386804.00, size=66771, txCount=115, blockNumber=20647175
#  on2024-08-31  Low=2493.71  BaseFeePerGas=724891186.00, gasUsed=10905206.00, burntFees=7905087710914316.00, size=47263, txCount=125, blockNumber=20647176
#  on2024-08-31  Low=2493.71  BaseFeePerGas=700155519.00, gasUsed=25516231.00, burntFees=17865329958728888.00, size=62060, txCount=147, blockNumber=20647177
#  on2024-08-31  Low=2493.71  BaseFeePerGas=761513828.00, gasUsed=6793674.00, burntFees=5173476693924072.00, size=26414, txCount=79, blockNumber=20647178
#  on2024-08-31  Low=2493.71  BaseFeePerGas=709436906.00, gasUsed=14735923.00, burntFees=10454207620174238.00, size=71689, txCount=163, blockNumber=20647179
#  on2024-08-31  Low=2493.71  BaseFeePerGas=707875690.00, gasUsed=17020384.00, burntFees=12048316068064960.00, size=88438, txCount=158, blockNumber=20647180
#  on2024-08-31  Low=2493.71  BaseFeePerGas=719793862.00, gasUsed=14938259.00, burntFees=10752467137166258.00, size=65050, txCount=155, blockNumber=20647181
#  on2024-08-31  Low=2493.71  BaseFeePerGas=719423523.00, gasUsed=9981102.00, burntFees=7180639564262346.00, size=43484, txCount=124, blockNumber=20647182
#  on2024-08-31  Low=2493.71  BaseFeePerGas=689334246.00, gasUsed=23920108.00, burntFees=16488949612418568.00, size=72752, txCount=201, blockNumber=20647183
#  on2024-08-31  Low=2493.71  BaseFeePerGas=740575378.00, gasUsed=9821083.00, burntFees=7273252255094374.00, size=52065, txCount=96, blockNumber=20647184
#  on2024-08-31  Low=2493.71  BaseFeePerGas=708613892.00, gasUsed=11693600.00, burntFees=8286247407491200.00, size=46265, txCount=118, blockNumber=20647185
#  on2024-08-31  Low=2493.71  BaseFeePerGas=689089218.00, gasUsed=11554455.00, burntFees=7962050360366190.00, size=45780, txCount=94, blockNumber=20647186
#  on2024-08-31  Low=2493.71  BaseFeePerGas=669303486.00, gasUsed=26363975.00, burntFees=17645500372316850.00, size=72973, txCount=155, blockNumber=20647187
#  on2024-08-31  Low=2493.71  BaseFeePerGas=732686386.00, gasUsed=15055208.00, burntFees=11030745939998288.00, size=69948, txCount=140, blockNumber=20647188
#  on2024-08-31  Low=2493.71  BaseFeePerGas=733023470.00, gasUsed=9576979.00, burntFees=7020150378697130.00, size=47650, txCount=111, blockNumber=20647189
#  on2024-08-31  Low=2493.71  BaseFeePerGas=699896790.00, gasUsed=1541957.00, burntFees=1079210754618030.00, size=8101, txCount=24, blockNumber=20647190
#  on2024-08-31  Low=2493.71  BaseFeePerGas=621403115.00, gasUsed=23368242.00, burntFees=14521098370873830.00, size=119015, txCount=262, blockNumber=20647191
#  on2024-08-31  Low=2493.71  BaseFeePerGas=664736878.00, gasUsed=16646709.00, burntFees=11065681369634502.00, size=74558, txCount=146, blockNumber=20647192
#  on2024-08-31  Low=2493.71  BaseFeePerGas=673858779.00, gasUsed=12531203.00, burntFees=8444261152981137.00, size=56364, txCount=132, blockNumber=20647193
#  on2024-08-31  Low=2493.71  BaseFeePerGas=659926629.00, gasUsed=21233634.00, burntFees=14012640507039786.00, size=78861, txCount=193, blockNumber=20647194
#  on2024-08-31  Low=2493.71  BaseFeePerGas=694207804.00, gasUsed=14349477.00, burntFees=9961518916718508.00, size=62363, txCount=107, blockNumber=20647195
#  on2024-08-31  Low=2493.71  BaseFeePerGas=690444487.00, gasUsed=12578245.00, burntFees=8684579916385315.00, size=74728, txCount=126, blockNumber=20647196
#  on2024-08-31  Low=2493.71  BaseFeePerGas=676510426.00, gasUsed=11980420.00, burntFees=8104879037858920.00, size=55553, txCount=109, blockNumber=20647197
#  on2024-08-31  Low=2493.71  BaseFeePerGas=659487282.00, gasUsed=18269564.00, burntFees=12048545105685048.00, size=83880, txCount=177, blockNumber=20647198
#  on2024-08-31  Low=2493.71  BaseFeePerGas=677455914.00, gasUsed=10768535.00, burntFees=7295207720865990.00, size=47942, txCount=120, blockNumber=20647199
#  on2024-08-31  Low=2493.71  BaseFeePerGas=653567323.00, gasUsed=14738460.00, burntFees=9632575847342580.00, size=71423, txCount=155, blockNumber=20647200
#  on2024-08-31  Low=2493.71  BaseFeePerGas=652142874.00, gasUsed=11781598.00, burntFees=7683285180032652.00, size=59345, txCount=127, blockNumber=20647201
#  on2024-08-31  Low=2493.71  BaseFeePerGas=634652392.00, gasUsed=18756510.00, burntFees=11903863937071920.00, size=76813, txCount=210, blockNumber=20647202
#  on2024-08-31  Low=2493.71  BaseFeePerGas=654519709.00, gasUsed=11483091.00, burntFees=7515909379740519.00, size=57807, txCount=111, blockNumber=20647203
#  on2024-08-31  Low=2493.71  BaseFeePerGas=635337324.00, gasUsed=16781093.00, burntFees=10661654720415132.00, size=76025, txCount=184, blockNumber=20647204
#  on2024-08-31  Low=2493.71  BaseFeePerGas=644767281.00, gasUsed=9379209.00, burntFees=6047407084860729.00, size=46319, txCount=126, blockNumber=20647205
#  on2024-08-31  Low=2493.71  BaseFeePerGas=614566430.00, gasUsed=29989319.00, burntFees=18430428715961168.00, size=45796, txCount=74, blockNumber=20647206
#  on2024-08-31  Low=2493.71  BaseFeePerGas=691332532.00, gasUsed=17227986.00, burntFees=11910267182640552.00, size=85032, txCount=198, blockNumber=20647207
#  on2024-08-31  Low=2493.71  BaseFeePerGas=704168192.00, gasUsed=11724567.00, burntFees=8256067146372864.00, size=61027, txCount=124, blockNumber=20647208
#  on2024-08-31  Low=2493.71  BaseFeePerGas=684947728.00, gasUsed=19593847.00, burntFees=13420760985429616.00, size=90552, txCount=221, blockNumber=20647209
#  on2024-08-31  Low=2493.71  BaseFeePerGas=711168936.00, gasUsed=9142019.00, burntFees=6501519925121784.00, size=35366, txCount=84, blockNumber=20647210
#  on2024-08-31  Low=2493.71  BaseFeePerGas=676452152.00, gasUsed=16114650.00, burntFees=10900789671226800.00, size=64577, txCount=199, blockNumber=20647211
#  on2024-08-31  Low=2493.71  BaseFeePerGas=682735546.00, gasUsed=14365496.00, burntFees=9807834755120816.00, size=60998, txCount=149, blockNumber=20647212
#  on2024-08-31  Low=2493.71  BaseFeePerGas=679125560.00, gasUsed=12604098.00, burntFees=8559765112544880.00, size=65836, txCount=142, blockNumber=20647213
#  on2024-08-31  Low=2493.71  BaseFeePerGas=665566241.00, gasUsed=16080273.00, burntFees=10702486854863792.00, size=37392, txCount=89, blockNumber=20647214
#  on2024-08-31  Low=2493.71  BaseFeePerGas=671557851.00, gasUsed=22963920.00, burntFees=15421600765735920.00, size=95445, txCount=227, blockNumber=20647215
#  on2024-08-31  Low=2493.71  BaseFeePerGas=716126459.00, gasUsed=17515831.00, burntFees=12543550030472428.00, size=80497, txCount=173, blockNumber=20647216
#  on2024-08-31  Low=2493.71  BaseFeePerGas=731140235.00, gasUsed=12871721.00, burntFees=9411033116794436.00, size=58108, txCount=128, blockNumber=20647217
#  on2024-08-31  Low=2493.71  BaseFeePerGas=718172982.00, gasUsed=15351727.00, burntFees=11025195558439914.00, size=64222, txCount=148, blockNumber=20647218
#  on2024-08-31  Low=2493.71  BaseFeePerGas=720277988.00, gasUsed=22146215.00, burntFees=15951431182015420.00, size=90026, txCount=271, blockNumber=20647219
#  on2024-08-31  Low=2493.71  BaseFeePerGas=763171832.00, gasUsed=20668467.00, burntFees=15773591825021544.00, size=88811, txCount=190, blockNumber=20647220
#  on2024-08-31  Low=2493.71  BaseFeePerGas=799221951.00, gasUsed=9803019.00, burntFees=7834787970870069.00, size=46873, txCount=92, blockNumber=20647221
#  on2024-08-31  Low=2493.71  BaseFeePerGas=764609107.00, gasUsed=15233886.00, burntFees=11647967970599802.00, size=65741, txCount=176, blockNumber=20647222
#  on2024-08-31  Low=2493.71  BaseFeePerGas=766099368.00, gasUsed=13613171.00, burntFees=10429041699575928.00, size=57057, txCount=132, blockNumber=20647223
#  on2024-08-31  Low=2493.71  BaseFeePerGas=757245628.00, gasUsed=7952169.00, burntFees=6021745208367132.00, size=34163, txCount=125, blockNumber=20647224
#  on2024-08-31  Low=2493.71  BaseFeePerGas=712771135.00, gasUsed=19328750.00, burntFees=13776975075631250.00, size=88663, txCount=203, blockNumber=20647225
#  on2024-08-31  Low=2493.71  BaseFeePerGas=738482868.00, gasUsed=15977817.00, burntFees=11799344122539156.00, size=66716, txCount=170, blockNumber=20647226
#  on2024-08-31  Low=2493.71  BaseFeePerGas=744500377.00, gasUsed=13406832.00, burntFees=9981391478375664.00, size=54466, txCount=146, blockNumber=20647227
#  on2024-08-31  Low=2493.71  BaseFeePerGas=734616093.00, gasUsed=11264785.00, burntFees=8275292345185005.00, size=56588, txCount=133, blockNumber=20647228
#  on2024-08-31  Low=2493.71  BaseFeePerGas=711749851.00, gasUsed=20560637.00, burntFees=14634030321215088.00, size=81010, txCount=263, blockNumber=20647229
#  on2024-08-31  Low=2493.71  BaseFeePerGas=744731372.00, gasUsed=14560046.00, burntFees=10843323033963112.00, size=71882, txCount=196, blockNumber=20647230
#  on2024-08-31  Low=2493.71  BaseFeePerGas=742000976.00, gasUsed=13874118.00, burntFees=10294609097139168.00, size=61472, txCount=204, blockNumber=20647231
#  on2024-08-31  Low=2493.71  BaseFeePerGas=735039264.00, gasUsed=5820722.00, burntFees=4278459214828608.00, size=26920, txCount=107, blockNumber=20647232
#  on2024-08-31  Low=2493.71  BaseFeePerGas=678813183.00, gasUsed=16778917.00, burntFees=11389750056062812.00, size=66213, txCount=161, blockNumber=20647233
#  on2024-08-31  Low=2493.71  BaseFeePerGas=688876118.00, gasUsed=23403549.00, burntFees=16122145982542782.00, size=97082, txCount=217, blockNumber=20647234
#  on2024-08-31  Low=2493.71  BaseFeePerGas=737117819.00, gasUsed=13328571.00, burntFees=9824727185906648.00, size=60818, txCount=154, blockNumber=20647235
#  on2024-08-31  Low=2493.71  BaseFeePerGas=726850819.00, gasUsed=8240470.00, burntFees=5989592368444930.00, size=37946, txCount=102, blockNumber=20647236
#  on2024-08-31  Low=2493.71  BaseFeePerGas=685907737.00, gasUsed=17634323.00, burntFees=12095518582457052.00, size=64642, txCount=136, blockNumber=20647237
#  on2024-08-31  Low=2493.71  BaseFeePerGas=700965258.00, gasUsed=13155827.00, burntFees=9221777667258366.00, size=52535, txCount=133, blockNumber=20647238
#  on2024-08-31  Low=2493.71  BaseFeePerGas=690192748.00, gasUsed=13973450.00, burntFees=9644373854540600.00, size=53853, txCount=156, blockNumber=20647239
#  on2024-08-31  Low=2493.71  BaseFeePerGas=684288437.00, gasUsed=15877727.00, burntFees=10864944991942700.00, size=83385, txCount=151, blockNumber=20647240
#  on2024-08-31  Low=2493.71  BaseFeePerGas=689293590.00, gasUsed=13029774.00, burntFees=8981339697348660.00, size=56865, txCount=159, blockNumber=20647241
#  on2024-08-31  Low=2493.71  BaseFeePerGas=677976389.00, gasUsed=14818263.00, burntFees=10046432439992308.00, size=60589, txCount=185, blockNumber=20647242
#  on2024-08-31  Low=2493.71  BaseFeePerGas=676949611.00, gasUsed=6148758.00, burntFees=4162399336233138.00, size=23452, txCount=101, blockNumber=20647243
#  on2024-08-31  Low=2493.71  BaseFeePerGas=627017571.00, gasUsed=22224298.00, burntFees=13935025349140158.00, size=95967, txCount=230, blockNumber=20647244
#  on2024-08-31  Low=2493.71  BaseFeePerGas=664765585.00, gasUsed=16797729.00, burntFees=11166552145356464.00, size=72281, txCount=203, blockNumber=20647245
#  on2024-08-31  Low=2493.71  BaseFeePerGas=674724488.00, gasUsed=10829066.00, burntFees=7306636012368208.00, size=50154, txCount=162, blockNumber=20647246
#  on2024-08-31  Low=2493.71  BaseFeePerGas=651272561.00, gasUsed=16147713.00, burntFees=10516562399802992.00, size=74809, txCount=220, blockNumber=20647247
#  on2024-08-31  Low=2493.71  BaseFeePerGas=657501510.00, gasUsed=11880257.00, burntFees=7811286916688070.00, size=48229, txCount=139, blockNumber=20647248
#  on2024-08-31  Low=2493.71  BaseFeePerGas=640407879.00, gasUsed=29980677.00, burntFees=19199861768554084.00, size=39227, txCount=91, blockNumber=20647249
#  on2024-08-31  Low=2493.71  BaseFeePerGas=720355742.00, gasUsed=6991619.00, burntFees=5036452892526298.00, size=33959, txCount=106, blockNumber=20647250
#  on2024-08-31  Low=2493.71  BaseFeePerGas=672281716.00, gasUsed=20369900.00, burntFees=13694311326748400.00, size=81858, txCount=191, blockNumber=20647251
#  on2024-08-31  Low=2493.71  BaseFeePerGas=702365762.00, gasUsed=10151230.00, burntFees=7129876394187260.00, size=43680, txCount=116, blockNumber=20647252
#  on2024-08-31  Low=2493.71  BaseFeePerGas=673985679.00, gasUsed=15257449.00, burntFees=10283302124072872.00, size=57996, txCount=190, blockNumber=20647253
#  on2024-08-31  Low=2493.71  BaseFeePerGas=675431653.00, gasUsed=12234669.00, burntFees=8263682706577857.00, size=58830, txCount=139, blockNumber=20647254
#  on2024-08-31  Low=2493.71  BaseFeePerGas=659866719.00, gasUsed=14034015.00, burntFees=9260579432446784.00, size=61095, txCount=171, blockNumber=20647255
#  on2024-08-31  Low=2493.71  BaseFeePerGas=654554875.00, gasUsed=14891961.00, burntFees=9747605670859876.00, size=63336, txCount=129, blockNumber=20647256
#  on2024-08-31  Low=2493.71  BaseFeePerGas=653886322.00, gasUsed=16039849.00, burntFees=10488237868045378.00, size=67941, txCount=157, blockNumber=20647257
#  on2024-08-31  Low=2493.71  BaseFeePerGas=659552513.00, gasUsed=17271490.00, burntFees=11391454632754370.00, size=55705, txCount=163, blockNumber=20647258
#  on2024-08-31  Low=2493.71  BaseFeePerGas=672037237.00, gasUsed=1709619.00, burntFees=1148927629082703.00, size=12156, txCount=26, blockNumber=20647259
#  on2024-08-31  Low=2493.71  BaseFeePerGas=597606980.00, gasUsed=29999249.00, burntFees=17927760597158020.00, size=55084, txCount=218, blockNumber=20647260
#  on2024-08-31  Low=2493.71  BaseFeePerGas=672304112.00, gasUsed=20157594.00, burntFees=13552033334226528.00, size=93784, txCount=198, blockNumber=20647261
#  on2024-08-31  Low=2493.71  BaseFeePerGas=701199709.00, gasUsed=13868276.00, burntFees=9724431095531684.00, size=62011, txCount=140, blockNumber=20647262
#  on2024-08-31  Low=2493.71  BaseFeePerGas=694586672.00, gasUsed=13203612.00, burntFees=9171052917459264.00, size=45672, txCount=141, blockNumber=20647263
#  on2024-08-31  Low=2493.71  BaseFeePerGas=684188779.00, gasUsed=13473409.00, burntFees=9218355252677612.00, size=57964, txCount=180, blockNumber=20647264
#  on2024-08-31  Low=2493.71  BaseFeePerGas=675484809.00, gasUsed=14224352.00, burntFees=9608333693868768.00, size=181657, txCount=141, blockNumber=20647265
#  on2024-08-31  Low=2493.71  BaseFeePerGas=671118656.00, gasUsed=8056966.00, burntFees=5407180193357696.00, size=18924, txCount=75, blockNumber=20647266
#  on2024-08-31  Low=2493.71  BaseFeePerGas=632288659.00, gasUsed=1760703.00, burntFees=1113272538767277.00, size=8080, txCount=25, blockNumber=20647267
#  on2024-08-31  Low=2493.71  BaseFeePerGas=562529848.00, gasUsed=29986342.00, burntFees=16868212407336016.00, size=137397, txCount=287, blockNumber=20647268
#  on2024-08-31  Low=2493.71  BaseFeePerGas=632782053.00, gasUsed=29987506.00, burntFees=18975555611029816.00, size=36339, txCount=94, blockNumber=20647269
#  on2024-08-31  Low=2493.71  BaseFeePerGas=711813926.00, gasUsed=18696855.00, burntFees=13308681761402730.00, size=68350, txCount=185, blockNumber=20647270
#  on2024-08-31  Low=2493.71  BaseFeePerGas=733742866.00, gasUsed=15021354.00, burntFees=11021811335160564.00, size=75558, txCount=143, blockNumber=20647271
#  on2024-08-31  Low=2493.71  BaseFeePerGas=733873435.00, gasUsed=13238560.00, burntFees=9715427501653600.00, size=55060, txCount=141, blockNumber=20647272
#  on2024-08-31  Low=2493.71  BaseFeePerGas=723101152.00, gasUsed=9572550.00, burntFees=6921921932577600.00, size=40757, txCount=111, blockNumber=20647273
#  on2024-08-31  Low=2493.71  BaseFeePerGas=690396191.00, gasUsed=18021998.00, burntFees=12442318773409618.00, size=86634, txCount=197, blockNumber=20647274
#  on2024-08-31  Low=2493.71  BaseFeePerGas=707782656.00, gasUsed=11323209.00, burntFees=8014370940463104.00, size=52665, txCount=118, blockNumber=20647275
#  on2024-08-31  Low=2493.71  BaseFeePerGas=686096249.00, gasUsed=5026429.00, burntFees=3448614082764821.00, size=23829, txCount=96, blockNumber=20647276
#  on2024-08-31  Low=2493.71  BaseFeePerGas=629072669.00, gasUsed=29913338.00, burntFees=18817663374359120.00, size=41099, txCount=115, blockNumber=20647277
#  on2024-08-31  Low=2493.71  BaseFeePerGas=707252446.00, gasUsed=16256949.00, burntFees=11497766944747254.00, size=75218, txCount=186, blockNumber=20647278
#  on2024-08-31  Low=2493.71  BaseFeePerGas=714660614.00, gasUsed=19351367.00, burntFees=13829659821959338.00, size=74974, txCount=173, blockNumber=20647279
#  on2024-08-31  Low=2493.71  BaseFeePerGas=740575202.00, gasUsed=8240786.00, burntFees=6102921756588772.00, size=34538, txCount=94, blockNumber=20647280
#  on2024-08-31  Low=2493.71  BaseFeePerGas=698860984.00, gasUsed=13963611.00, burntFees=9758622923653224.00, size=73814, txCount=129, blockNumber=20647281
#  on2024-08-31  Low=2493.71  BaseFeePerGas=692825219.00, gasUsed=7978556.00, burntFees=5527744808003764.00, size=35662, txCount=98, blockNumber=20647282
#  on2024-08-31  Low=2493.71  BaseFeePerGas=652286607.00, gasUsed=26071094.00, burntFees=17005825446038058.00, size=111258, txCount=198, blockNumber=20647283
#  on2024-08-31  Low=2493.71  BaseFeePerGas=712465993.00, gasUsed=21245033.00, burntFees=15136363532662768.00, size=79770, txCount=230, blockNumber=20647284
#  on2024-08-31  Low=2493.71  BaseFeePerGas=749544106.00, gasUsed=15533519.00, burntFees=11643057611889014.00, size=73178, txCount=155, blockNumber=20647285
#  on2024-08-31  Low=2493.71  BaseFeePerGas=752876572.00, gasUsed=7386527.00, burntFees=5561143126745444.00, size=32395, txCount=80, blockNumber=20647286
#  on2024-08-31  Low=2493.71  BaseFeePerGas=705109860.00, gasUsed=15810953.00, burntFees=11148458856296580.00, size=65904, txCount=193, blockNumber=20647287
#  on2024-08-31  Low=2493.71  BaseFeePerGas=709874951.00, gasUsed=14405850.00, burntFees=10226352062863350.00, size=71630, txCount=149, blockNumber=20647288
#  on2024-08-31  Low=2493.71  BaseFeePerGas=706360183.00, gasUsed=10972832.00, burntFees=7750771619548256.00, size=47528, txCount=97, blockNumber=20647289
#  on2024-08-31  Low=2493.71  BaseFeePerGas=682654924.00, gasUsed=15637625.00, burntFees=10675101705915500.00, size=71835, txCount=180, blockNumber=20647290
#  on2024-08-31  Low=2493.71  BaseFeePerGas=686282239.00, gasUsed=17182840.00, burntFees=11792277907578760.00, size=59695, txCount=154, blockNumber=20647291
#  on2024-08-31  Low=2493.71  BaseFeePerGas=698765941.00, gasUsed=14558435.00, burntFees=10172938532262336.00, size=66833, txCount=175, blockNumber=20647292
#  on2024-08-31  Low=2493.71  BaseFeePerGas=696194687.00, gasUsed=12101744.00, burntFees=8425169876234128.00, size=63777, txCount=141, blockNumber=20647293
#  on2024-08-31  Low=2493.71  BaseFeePerGas=679380101.00, gasUsed=20209510.00, burntFees=13729938944960510.00, size=73271, txCount=194, blockNumber=20647294
#  on2024-08-31  Low=2493.71  BaseFeePerGas=708873746.00, gasUsed=6850618.00, burntFees=4856223244075028.00, size=31797, txCount=91, blockNumber=20647295
#  on2024-08-31  Low=2493.71  BaseFeePerGas=660733055.00, gasUsed=14679859.00, burntFees=9699468084039244.00, size=74263, txCount=183, blockNumber=20647296
#  on2024-08-31  Low=2493.71  BaseFeePerGas=658970324.00, gasUsed=20138988.00, burntFees=13270995447392112.00, size=52731, txCount=127, blockNumber=20647297
#  on2024-08-31  Low=2493.71  BaseFeePerGas=687190662.00, gasUsed=15470056.00, burntFees=10630878023817072.00, size=65114, txCount=148, blockNumber=20647298
#  on2024-08-31  Low=2493.71  BaseFeePerGas=689882479.00, gasUsed=11753554.00, burntFees=8108570970580366.00, size=60860, txCount=134, blockNumber=20647299
#  on2024-08-31  Low=2493.71  BaseFeePerGas=671218594.00, gasUsed=15541735.00, burntFees=10431901515020590.00, size=77287, txCount=194, blockNumber=20647300
#  on2024-08-31  Low=2493.71  BaseFeePerGas=674248782.00, gasUsed=14895999.00, burntFees=10043609182423218.00, size=66738, txCount=210, blockNumber=20647301
#  on2024-08-31  Low=2493.71  BaseFeePerGas=673664428.00, gasUsed=20686454.00, burntFees=13935728201258312.00, size=83506, txCount=190, blockNumber=20647302
#  on2024-08-31  Low=2493.71  BaseFeePerGas=705587442.00, gasUsed=14345647.00, burntFees=10122108370564974.00, size=64046, txCount=168, blockNumber=20647303
#  on2024-08-31  Low=2493.71  BaseFeePerGas=701739915.00, gasUsed=13340103.00, burntFees=9361282745311244.00, size=62269, txCount=205, blockNumber=20647304
# ...
#  on2024-08-31  Low=2493.71  BaseFeePerGas=583543090.00, gasUsed=29979999.00, burntFees=17494621254656910.00, size=34924, txCount=95, blockNumber=20651894
#  on2024-08-31  Low=2493.71  BaseFeePerGas=656388714.00, gasUsed=6359573.00, burntFees=4174351943059122.00, size=26005, txCount=82, blockNumber=20651895
#  on2024-08-31  Low=2493.71  BaseFeePerGas=609126391.00, gasUsed=12156113.00, burntFees=7404609240278183.00, size=53758, txCount=129, blockNumber=20651896
#  on2024-08-31  Low=2493.71  BaseFeePerGas=594690670.00, gasUsed=12461717.00, burntFees=7410866832080390.00, size=60841, txCount=170, blockNumber=20651897
#  on2024-08-31  Low=2493.71  BaseFeePerGas=582111560.00, gasUsed=11655872.00, burntFees=6785017833080320.00, size=48167, txCount=118, blockNumber=20651898
#  on2024-08-31  Low=2493.71  BaseFeePerGas=565889431.00, gasUsed=29993604.00, burntFees=16973063501199324.00, size=75058, txCount=63, blockNumber=20651899
#  on2024-08-31  Low=2493.71  BaseFeePerGas=636595447.00, gasUsed=11128263.00, burntFees=7084201558818561.00, size=58650, txCount=119, blockNumber=20651900
#  on2024-08-31  Low=2493.71  BaseFeePerGas=616056030.00, gasUsed=15014828.00, burntFees=9249975328812840.00, size=40655, txCount=110, blockNumber=20651901
#  on2024-08-31  Low=2493.71  BaseFeePerGas=616132153.00, gasUsed=6190916.00, burntFees=3814422404122148.00, size=35083, txCount=92, blockNumber=20651902
#  on2024-08-31  Low=2493.71  BaseFeePerGas=570902488.00, gasUsed=29996791.00, burntFees=17125242613916008.00, size=49395, txCount=86, blockNumber=20651903
#  on2024-08-31  Low=2493.71  BaseFeePerGas=642250032.00, gasUsed=14689203.00, burntFees=9434141096804496.00, size=68910, txCount=157, blockNumber=20651904
#  on2024-08-31  Low=2493.71  BaseFeePerGas=640586621.00, gasUsed=3069629.00, burntFees=1966363268833609.00, size=16713, txCount=51, blockNumber=20651905
#  on2024-08-31  Low=2493.71  BaseFeePerGas=576899654.00, gasUsed=19384225.00, burntFees=11182752695558150.00, size=119507, txCount=126, blockNumber=20651906
#  on2024-08-31  Low=2493.71  BaseFeePerGas=597976803.00, gasUsed=635491.00, burntFees=380008876515273.00, size=3942, txCount=14, blockNumber=20651907
#  on2024-08-31  Low=2493.71  BaseFeePerGas=526396444.00, gasUsed=22302115.00, burntFees=11739754029679060.00, size=99876, txCount=407, blockNumber=20651908
#  on2024-08-31  Low=2493.71  BaseFeePerGas=558428172.00, gasUsed=29951331.00, burntFees=16725667019296932.00, size=62805, txCount=132, blockNumber=20651909
#  on2024-08-31  Low=2493.71  BaseFeePerGas=628005208.00, gasUsed=554353.00, burntFees=348136571070424.00, size=4758, txCount=14, blockNumber=20651910
#  on2024-08-31  Low=2493.71  BaseFeePerGas=552405696.00, gasUsed=23480002.00, burntFees=12970486846891392.00, size=103204, txCount=220, blockNumber=20651911
#  on2024-08-31  Low=2493.71  BaseFeePerGas=591442374.00, gasUsed=29989460.00, burntFees=17737037417378040.00, size=37869, txCount=94, blockNumber=20651912
#  on2024-08-31  Low=2493.71  BaseFeePerGas=665320722.00, gasUsed=6814558.00, burntFees=4533866648670876.00, size=36435, txCount=77, blockNumber=20651913
#  on2024-08-31  Low=2493.71  BaseFeePerGas=619937854.00, gasUsed=15770734.00, burntFees=9776874991964836.00, size=75507, txCount=157, blockNumber=20651914
#  on2024-08-31  Low=2493.71  BaseFeePerGas=623919580.00, gasUsed=8433521.00, burntFees=5261838880241180.00, size=38403, txCount=96, blockNumber=20651915
#  on2024-08-31  Low=2493.71  BaseFeePerGas=589778290.00, gasUsed=13849173.00, burntFees=8167941569854170.00, size=59806, txCount=157, blockNumber=20651916
#  on2024-08-31  Low=2493.71  BaseFeePerGas=584122184.00, gasUsed=15101650.00, burntFees=8821208780003600.00, size=104237, txCount=118, blockNumber=20651917
#  on2024-08-31  Low=2493.71  BaseFeePerGas=584616984.00, gasUsed=29983893.00, burntFees=17529093094238712.00, size=37243, txCount=91, blockNumber=20651918
#  on2024-08-31  Low=2493.71  BaseFeePerGas=657615636.00, gasUsed=7265801.00, burntFees=4778104345664436.00, size=30882, txCount=104, blockNumber=20651919
#  on2024-08-31  Low=2493.71  BaseFeePerGas=615231218.00, gasUsed=5214785.00, burntFees=3208298527158130.00, size=29118, txCount=89, blockNumber=20651920
#  on2024-08-31  Low=2493.71  BaseFeePerGas=565063137.00, gasUsed=11986472.00, burntFees=6773113469882664.00, size=55470, txCount=144, blockNumber=20651921
#  on2024-08-31  Low=2493.71  BaseFeePerGas=550872858.00, gasUsed=29996836.00, burntFees=16524442778277288.00, size=58343, txCount=86, blockNumber=20651922
#  on2024-08-31  Low=2493.71  BaseFeePerGas=619717440.00, gasUsed=298109.00, burntFees=184743346320960.00, size=2822, txCount=13, blockNumber=20651923
#  on2024-08-31  Low=2493.71  BaseFeePerGas=543792288.00, gasUsed=20404546.00, burntFees=11095834754941248.00, size=112449, txCount=230, blockNumber=20651924
#  on2024-08-31  Low=2493.71  BaseFeePerGas=568283541.00, gasUsed=24790043.00, burntFees=14087773417582264.00, size=140558, txCount=252, blockNumber=20651925
#  on2024-08-31  Low=2493.71  BaseFeePerGas=614646210.00, gasUsed=564495.00, burntFees=346964712313950.00, size=3844, txCount=19, blockNumber=20651926
#  on2024-08-31  Low=2493.71  BaseFeePerGas=540706807.00, gasUsed=21611940.00, burntFees=11685723070475580.00, size=88833, txCount=333, blockNumber=20651927
#  on2024-08-31  Low=2493.71  BaseFeePerGas=570499481.00, gasUsed=29994879.00, burntFees=17112062902157800.00, size=40182, txCount=101, blockNumber=20651928
#  on2024-08-31  Low=2493.71  BaseFeePerGas=641787570.00, gasUsed=6611315.00, burntFees=4243059788354550.00, size=49215, txCount=80, blockNumber=20651929
#  on2024-08-31  Low=2493.71  BaseFeePerGas=596922956.00, gasUsed=11762520.00, burntFees=7021318208409120.00, size=81978, txCount=130, blockNumber=20651930
#  on2024-08-31  Low=2493.71  BaseFeePerGas=580818572.00, gasUsed=29980825.00, burntFees=17413419963881900.00, size=63784, txCount=141, blockNumber=20651931
#  on2024-08-31  Low=2493.71  BaseFeePerGas=653328083.00, gasUsed=11954999.00, burntFees=7810536578936917.00, size=71479, txCount=123, blockNumber=20651932
#  on2024-08-31  Low=2493.71  BaseFeePerGas=636749878.00, gasUsed=3977164.00, burntFees=2532458691785992.00, size=36873, txCount=66, blockNumber=20651933
#  on2024-08-31  Low=2493.71  BaseFeePerGas=578259966.00, gasUsed=20671640.00, burntFees=11953581843564240.00, size=81597, txCount=181, blockNumber=20651934
#  on2024-08-31  Low=2493.71  BaseFeePerGas=605590652.00, gasUsed=17868687.00, burntFees=10821109810713924.00, size=268667, txCount=124, blockNumber=20651935
#  on2024-08-31  Low=2493.71  BaseFeePerGas=620067735.00, gasUsed=13731012.00, burntFees=8514157510097820.00, size=229994, txCount=86, blockNumber=20651936
#  on2024-08-31  Low=2493.71  BaseFeePerGas=613510581.00, gasUsed=28539535.00, burntFees=17509306699319836.00, size=53661, txCount=123, blockNumber=20651937
#  on2024-08-31  Low=2493.71  BaseFeePerGas=682732647.00, gasUsed=17203352.00, burntFees=11745290048232744.00, size=128929, txCount=78, blockNumber=20651938
#  on2024-08-31  Low=2493.71  BaseFeePerGas=695268483.00, gasUsed=16066870.00, burntFees=11170788331458210.00, size=45835, txCount=140, blockNumber=20651939
#  on2024-08-31  Low=2493.71  BaseFeePerGas=701449825.00, gasUsed=11667844.00, burntFees=8184407131927300.00, size=45465, txCount=119, blockNumber=20651940
#  on2024-08-31  Low=2493.71  BaseFeePerGas=681971990.00, gasUsed=9545740.00, burntFees=6509927303822600.00, size=51115, txCount=128, blockNumber=20651941
#  on2024-08-31  Low=2493.71  BaseFeePerGas=650974886.00, gasUsed=19305922.00, burntFees=12567670373074892.00, size=119965, txCount=128, blockNumber=20651942
#  on2024-08-31  Low=2493.71  BaseFeePerGas=674333611.00, gasUsed=11932718.00, burntFees=8046632817984698.00, size=52430, txCount=113, blockNumber=20651943
#  on2024-08-31  Low=2493.71  BaseFeePerGas=657097184.00, gasUsed=4907865.00, burntFees=3224944270952160.00, size=27044, txCount=87, blockNumber=20651944
#  on2024-08-31  Low=2493.71  BaseFeePerGas=601834572.00, gasUsed=654910.00, burntFees=394147479548520.00, size=4840, txCount=18, blockNumber=20651945
#  on2024-08-31  Low=2493.71  BaseFeePerGas=529889813.00, gasUsed=26610954.00, burntFees=14100873438811602.00, size=112804, txCount=399, blockNumber=20651946
#  on2024-08-31  Low=2493.71  BaseFeePerGas=581160865.00, gasUsed=29990778.00, burntFees=17429466484502970.00, size=167253, txCount=98, blockNumber=20651947
#  on2024-08-31  Low=2493.71  BaseFeePerGas=653761310.00, gasUsed=14022868.00, burntFees=9167608553637080.00, size=60661, txCount=172, blockNumber=20651948
#  on2024-08-31  Low=2493.71  BaseFeePerGas=648437885.00, gasUsed=12420763.00, burntFees=8054093289806255.00, size=52905, txCount=122, blockNumber=20651949
#  on2024-08-31  Low=2493.71  BaseFeePerGas=634500594.00, gasUsed=18616847.00, burntFees=11812400479907118.00, size=57852, txCount=127, blockNumber=20651950
#  on2024-08-31  Low=2493.71  BaseFeePerGas=653624690.00, gasUsed=10837586.00, burntFees=7083713789598340.00, size=44826, txCount=139, blockNumber=20651951
#  on2024-08-31  Low=2493.71  BaseFeePerGas=630952552.00, gasUsed=9333802.00, burntFees=5889186191762704.00, size=43441, txCount=115, blockNumber=20651952
#  on2024-08-31  Low=2493.71  BaseFeePerGas=601160035.00, gasUsed=10818761.00, burntFees=6503806741416635.00, size=51364, txCount=122, blockNumber=20651953
#  on2024-08-31  Low=2493.71  BaseFeePerGas=580213421.00, gasUsed=13481737.00, burntFees=7822284745792277.00, size=75146, txCount=148, blockNumber=20651954
#  on2024-08-31  Low=2493.71  BaseFeePerGas=572872450.00, gasUsed=29907489.00, burntFees=17133176496778050.00, size=43072, txCount=93, blockNumber=20651955
#  on2024-08-31  Low=2493.71  BaseFeePerGas=644039864.00, gasUsed=10783679.00, burntFees=6945119156579656.00, size=60001, txCount=121, blockNumber=20651956
#  on2024-08-31  Low=2493.71  BaseFeePerGas=621410874.00, gasUsed=5591086.00, burntFees=3474361637869164.00, size=38378, txCount=75, blockNumber=20651957
#  on2024-08-31  Low=2493.71  BaseFeePerGas=572687529.00, gasUsed=20694402.00, burntFees=11851425945512658.00, size=89955, txCount=183, blockNumber=20651958
#  on2024-08-31  Low=2493.71  BaseFeePerGas=599863470.00, gasUsed=13379793.00, burntFees=8026049056861710.00, size=54220, txCount=127, blockNumber=20651959
#  on2024-08-31  Low=2493.71  BaseFeePerGas=591764279.00, gasUsed=13404345.00, burntFees=7932212554392255.00, size=63438, txCount=134, blockNumber=20651960
#  on2024-08-31  Low=2493.71  BaseFeePerGas=583895516.00, gasUsed=25948148.00, burntFees=15151007265704368.00, size=29329, txCount=74, blockNumber=20651961
#  on2024-08-31  Low=2493.71  BaseFeePerGas=637043803.00, gasUsed=27466317.00, burntFees=17497247036083552.00, size=68770, txCount=127, blockNumber=20651962
#  on2024-08-31  Low=2493.71  BaseFeePerGas=703223719.00, gasUsed=3351021.00, burntFees=2356517450067099.00, size=29154, txCount=41, blockNumber=20651963
#  on2024-08-31  Low=2493.71  BaseFeePerGas=634958400.00, gasUsed=12034443.00, burntFees=7641370672171200.00, size=69385, txCount=139, blockNumber=20651964
#  on2024-08-31  Low=2493.71  BaseFeePerGas=619266689.00, gasUsed=8087710.00, burntFees=5008449393292190.00, size=58934, txCount=104, blockNumber=20651965
#  on2024-08-31  Low=2493.71  BaseFeePerGas=583554717.00, gasUsed=15547071.00, burntFees=9072566617583908.00, size=81187, txCount=157, blockNumber=20651966
#  on2024-08-31  Low=2493.71  BaseFeePerGas=586215099.00, gasUsed=29982316.00, burntFees=17576086342189284.00, size=77923, txCount=105, blockNumber=20651967
#  on2024-08-31  Low=2493.71  BaseFeePerGas=659405597.00, gasUsed=10698724.00, burntFees=7054798486358228.00, size=67857, txCount=150, blockNumber=20651968
#  on2024-08-31  Low=2493.71  BaseFeePerGas=635769885.00, gasUsed=10611567.00, burntFees=6746514731259795.00, size=75497, txCount=95, blockNumber=20651969
#  on2024-08-31  Low=2493.71  BaseFeePerGas=612519606.00, gasUsed=15636140.00, burntFees=9577442312160840.00, size=84168, txCount=166, blockNumber=20651970
#  on2024-08-31  Low=2493.71  BaseFeePerGas=615766674.00, gasUsed=24321796.00, burntFees=14976551428626504.00, size=48593, txCount=95, blockNumber=20651971
#  on2024-08-31  Low=2493.71  BaseFeePerGas=663600434.00, gasUsed=13930773.00, burntFees=9244467008755482.00, size=65548, txCount=149, blockNumber=20651972
#  on2024-08-31  Low=2493.71  BaseFeePerGas=657687605.00, gasUsed=20790200.00, burntFees=13673456845471000.00, size=92134, txCount=129, blockNumber=20651973
#  on2024-08-31  Low=2493.71  BaseFeePerGas=689422128.00, gasUsed=9687166.00, burntFees=6678546598009248.00, size=54986, txCount=104, blockNumber=20651974
#  on2024-08-31  Low=2493.71  BaseFeePerGas=658898917.00, gasUsed=11071153.00, burntFees=7294770721641301.00, size=56936, txCount=126, blockNumber=20651975
#  on2024-08-31  Low=2493.71  BaseFeePerGas=637326309.00, gasUsed=29959132.00, burntFees=19093743018403788.00, size=59545, txCount=129, blockNumber=20651976
#  on2024-08-31  Low=2493.71  BaseFeePerGas=716775045.00, gasUsed=9038982.00, burntFees=6478916729804190.00, size=81451, txCount=104, blockNumber=20651977
#  on2024-08-31  Low=2493.71  BaseFeePerGas=681169138.00, gasUsed=4889392.00, burntFees=3330502933984096.00, size=30361, txCount=59, blockNumber=20651978
#  on2024-08-31  Low=2493.71  BaseFeePerGas=623777187.00, gasUsed=29997260.00, burntFees=18711606460507620.00, size=59832, txCount=166, blockNumber=20651979
#  on2024-08-31  Low=2493.71  BaseFeePerGas=701735092.00, gasUsed=4769107.00, burntFees=3346649739402844.00, size=26396, txCount=70, blockNumber=20651980
#  on2024-08-31  Low=2493.71  BaseFeePerGas=641906954.00, gasUsed=19341913.00, burntFees=12415708458363002.00, size=112740, txCount=180, blockNumber=20651981
#  on2024-08-31  Low=2493.71  BaseFeePerGas=665132821.00, gasUsed=9839134.00, burntFees=6544330953617014.00, size=48498, txCount=111, blockNumber=20651982
#  on2024-08-31  Low=2493.71  BaseFeePerGas=636527310.00, gasUsed=28456347.00, burntFees=18113242008336568.00, size=62900, txCount=129, blockNumber=20651983
#  on2024-08-31  Low=2493.71  BaseFeePerGas=707905079.00, gasUsed=5789976.00, burntFees=4098753417688104.00, size=32787, txCount=90, blockNumber=20651984
#  on2024-08-31  Low=2493.71  BaseFeePerGas=653573223.00, gasUsed=14424491.00, burntFees=9427461073004492.00, size=41719, txCount=77, blockNumber=20651985
#  on2024-08-31  Low=2493.71  BaseFeePerGas=650438746.00, gasUsed=20018932.00, burntFees=13021089026339272.00, size=13815, txCount=49, blockNumber=20651986
#  on2024-08-31  Low=2493.71  BaseFeePerGas=677642977.00, gasUsed=20798478.00, burntFees=14093942548989006.00, size=82843, txCount=189, blockNumber=20651987
#  on2024-08-31  Low=2493.71  BaseFeePerGas=710387126.00, gasUsed=5745592.00, burntFees=4081594588048592.00, size=30021, txCount=90, blockNumber=20651988
#  on2024-08-31  Low=2493.71  BaseFeePerGas=655602024.00, gasUsed=28767207.00, burntFees=18859839134026968.00, size=118415, txCount=119, blockNumber=20651989
#  on2024-08-31  Low=2493.71  BaseFeePerGas=730817097.00, gasUsed=10083731.00, burntFees=7369363016348907.00, size=57707, txCount=102, blockNumber=20651990
#  on2024-08-31  Low=2493.71  BaseFeePerGas=700876319.00, gasUsed=8689924.00, burntFees=6090561945509756.00, size=42741, txCount=101, blockNumber=20651991
#  on2024-08-31  Low=2493.71  BaseFeePerGas=664021463.00, gasUsed=11815377.00, burntFees=7845663921436551.00, size=52852, txCount=120, blockNumber=20651992
#  on2024-08-31  Low=2493.71  BaseFeePerGas=646399313.00, gasUsed=1515986.00, burntFees=979932308917618.00, size=10275, txCount=13, blockNumber=20651993
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c30ea6ecaa83> in <cell line: 0>()
#      45             row = merged.loc[idx]
#      46             print(
# ---> 47                 f" on{row['Date'].date()}  "
#      48                 f"{col}={row[col]:.2f}  "
#      49                 f"BaseFeePerGas={row['baseFeePerGas']:.2f}, "
#
# ValueError: Unknown format code 'f' for object of type 'str'

# %%
K = 10000
price_cols = ['Open','High','Low','Close','Adj Close','Volume']
gold_rows = []

for col in price_cols:
    # —— MAX & nearest K —— #
    max_val  = merged[col].max()
    idxs_max = (merged[col] - max_val).abs().nsmallest(K).index

    print(f"\n=== MAX & {K} NEAREST for {col} (target={max_val:.2f}) ===")
    for idx in idxs_max:
        row = merged.loc[idx]
        date_str = row['Date'].strftime('%Y-%m-%d')
        print(
            f" on {date_str}  "
            f"{col}={float(row[col]):.2f}  "
            f"→ blockNumber={int(row['blockNumber'])}, "
            f"BaseFeePerGas={float(row['baseFeePerGas']):.2f}, "
            f"burntFees={float(row['burntFees']):.2f}, "
            f"txFees={float(row['txFees']):.2f}, "
            f"size={int(row['size'])}, "
            f"txCount={int(row['transactionCount'])}"
        )
        gold_rows.append({
            'blockNumber': int(row['blockNumber']),
            'label':       1,   # high
        })

    # —— MIN & nearest K —— #
    min_val  = merged[col].min()
    idxs_min = (merged[col] - min_val).abs().nsmallest(K).index

    print(f"\n=== MIN & {K} NEAREST for {col} (target={min_val:.2f}) ===")
    for idx in idxs_min:
        row = merged.loc[idx]
        date_str = row['Date'].strftime('%Y-%m-%d')
        print(
            f" on {date_str}  "
            f"{col}={float(row[col]):.2f}  "
            f"→ blockNumber={int(row['blockNumber'])}, "
            f"BaseFeePerGas={float(row['baseFeePerGas']):.2f}, "
            f"burntFees={float(row['burntFees']):.2f}, "
            f"txFees={float(row['txFees']):.2f}, "
            f"size={int(row['size'])}, "
            f"txCount={int(row['transactionCount'])}"
        )
        gold_rows.append({
            'blockNumber': int(row['blockNumber']),
            'label':       0,   # low
        })

gold_df = (
    pd.DataFrame(gold_rows)
      .drop_duplicates(subset='blockNumber')
      .reset_index(drop=True)
)

print("\nGold‐standard table:")
print(gold_df.head(), "\n… total rows:", len(gold_df))
# Out:
# Streaming output truncated to the last 5000 lines.
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100135, BaseFeePerGas=9619773502.00, burntFees=129427462924561136.00, txFees=170893813734222912.00, size=121968, txCount=159
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100136, BaseFeePerGas=9495864006.00, burntFees=93987032750770080.00, txFees=137235993021307296.00, size=110732, txCount=113
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100137, BaseFeePerGas=9092106279.00, burntFees=133431151144826832.00, txFees=156768377688167136.00, size=120098, txCount=134
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100138, BaseFeePerGas=9067519254.00, burntFees=138875540651276608.00, txFees=207117101656827296.00, size=373374, txCount=126
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100139, BaseFeePerGas=9091375519.00, burntFees=102657639521798960.00, txFees=111909403994414608.00, size=234015, txCount=115
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100140, BaseFeePerGas=8810433909.00, burntFees=150518977106422272.00, txFees=159710719812767648.00, size=195878, txCount=169
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100141, BaseFeePerGas=8963454479.00, burntFees=169609246395617536.00, txFees=215402928962991424.00, size=300092, txCount=153
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100142, BaseFeePerGas=9256433055.00, burntFees=122341007556606464.00, txFees=828635955947927424.00, size=119881, txCount=162
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100143, BaseFeePerGas=9118887320.00, burntFees=190027197979480576.00, txFees=375880598266077568.00, size=303651, txCount=125
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100144, BaseFeePerGas=9562586388.00, burntFees=141892047471740992.00, txFees=176840160814502688.00, size=163336, txCount=127
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100145, BaseFeePerGas=9549696819.00, burntFees=96607808023379712.00, txFees=106440994575517632.00, size=99187, txCount=101
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100146, BaseFeePerGas=9161049784.00, burntFees=191643738139807872.00, txFees=224062056121802656.00, size=261686, txCount=247
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100147, BaseFeePerGas=9612949712.00, burntFees=110398459799107776.00, txFees=172737078137413056.00, size=164632, txCount=115
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100148, BaseFeePerGas=9331318163.00, burntFees=137887806061744096.00, txFees=176929278376150752.00, size=280209, txCount=130
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100149, BaseFeePerGas=9313968444.00, burntFees=147009070008931680.00, txFees=286500086184295872.00, size=136783, txCount=127
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100150, BaseFeePerGas=9374797971.00, burntFees=126555957065725808.00, txFees=163356966627623040.00, size=177640, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100151, BaseFeePerGas=9258612092.00, burntFees=75113342248874336.00, txFees=93551229348511600.00, size=71928, txCount=97
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100152, BaseFeePerGas=8727230684.00, burntFees=208624580409480256.00, txFees=237126148301720416.00, size=303066, txCount=195
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100153, BaseFeePerGas=9374865018.00, burntFees=133795157953875408.00, txFees=189702413752360384.00, size=147792, txCount=149
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100154, BaseFeePerGas=9317966541.00, burntFees=139245520902499952.00, txFees=157392699850542304.00, size=255054, txCount=126
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100155, BaseFeePerGas=9313600065.00, burntFees=135133575269502816.00, txFees=176030054425622560.00, size=332380, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100156, BaseFeePerGas=9275513185.00, burntFees=122226702219386112.00, txFees=184116006478634656.00, size=59255, txCount=163
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100157, BaseFeePerGas=9134629889.00, burntFees=215581037982544160.00, txFees=275251289380671072.00, size=248371, txCount=246
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100158, BaseFeePerGas=9789309802.00, burntFees=98496109714493392.00, txFees=110270526500837376.00, size=278844, txCount=103
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100159, BaseFeePerGas=9386446992.00, burntFees=191792877156762336.00, txFees=282869313220808640.00, size=232275, txCount=147
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100160, BaseFeePerGas=9811415094.00, burntFees=124451001156729856.00, txFees=315979719923186752.00, size=102253, txCount=125
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100161, BaseFeePerGas=9622079884.00, burntFees=140839980527368736.00, txFees=223431114699710368.00, size=278137, txCount=130
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100162, BaseFeePerGas=9592986403.00, burntFees=134608957880651248.00, txFees=182657999438399552.00, size=180109, txCount=130
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100163, BaseFeePerGas=9516700907.00, burntFees=137405154006154432.00, txFees=162935070594952576.00, size=328753, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100164, BaseFeePerGas=9472157313.00, burntFees=131069082387174896.00, txFees=185946042013758464.00, size=121833, txCount=127
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100165, BaseFeePerGas=9380380003.00, burntFees=187053576056262816.00, txFees=245179384321164736.00, size=134555, txCount=152
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100166, BaseFeePerGas=9766612303.00, burntFees=131784230219174320.00, txFees=182613781935954368.00, size=168765, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100167, BaseFeePerGas=9643987684.00, burntFees=131037711588313056.00, txFees=191847558598996544.00, size=120713, txCount=121
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100168, BaseFeePerGas=9530470154.00, burntFees=230251651008257152.00, txFees=324566632409369408.00, size=411481, txCount=150
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100169, BaseFeePerGas=10257925143.00, burntFees=167512994667330016.00, txFees=250613798282992928.00, size=331719, txCount=142
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100170, BaseFeePerGas=10371626122.00, burntFees=112367099737220608.00, txFees=147766423994525504.00, size=99093, txCount=116
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100171, BaseFeePerGas=10011565355.00, burntFees=136370124695881952.00, txFees=242395759010635136.00, size=226599, txCount=126
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100172, BaseFeePerGas=9896537392.00, burntFees=183026710975708864.00, txFees=236617090349731488.00, size=147160, txCount=140
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100173, BaseFeePerGas=10184692809.00, burntFees=130865949247441904.00, txFees=173303688519093792.00, size=165884, txCount=108
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100174, BaseFeePerGas=10002155785.00, burntFees=208978791624424384.00, txFees=247870975279881536.00, size=375073, txCount=147
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100175, BaseFeePerGas=10493376242.00, burntFees=130421753576768320.00, txFees=148704445428889216.00, size=120154, txCount=106
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100176, BaseFeePerGas=10268552159.00, burntFees=160179925538205088.00, txFees=224835299655397984.00, size=218789, txCount=161
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100177, BaseFeePerGas=10319815851.00, burntFees=168152648088203360.00, txFees=189637966730592224.00, size=207399, txCount=107
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100178, BaseFeePerGas=10431110937.00, burntFees=98817961177244560.00, txFees=104759562224109536.00, size=82077, txCount=106
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100179, BaseFeePerGas=9950705080.00, burntFees=197149230010252128.00, txFees=224809254242983648.00, size=149154, txCount=154
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100180, BaseFeePerGas=10349777195.00, burntFees=237119677852207360.00, txFees=282525795822295328.00, size=271056, txCount=449
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100181, BaseFeePerGas=11032052361.00, burntFees=134597183657365072.00, txFees=169984904045583904.00, size=162208, txCount=126
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100182, BaseFeePerGas=10774689014.00, burntFees=165559981726389952.00, txFees=216762480498574432.00, size=224465, txCount=165
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100183, BaseFeePerGas=10807519401.00, burntFees=132108101859911120.00, txFees=184621815842528288.00, size=145263, txCount=142
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100184, BaseFeePerGas=10557480325.00, burntFees=171271437844756032.00, txFees=231286822862592128.00, size=244084, txCount=125
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100185, BaseFeePerGas=10665057266.00, burntFees=270875241153972672.00, txFees=460293008668712064.00, size=316500, txCount=164
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100186, BaseFeePerGas=11589218784.00, burntFees=168297650097651360.00, txFees=187678969533560000.00, size=215908, txCount=136
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100187, BaseFeePerGas=11543046854.00, burntFees=144241555653131520.00, txFees=164582617793987584.00, size=125464, txCount=133
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100188, BaseFeePerGas=11302178962.00, burntFees=200604725249762112.00, txFees=270044335970936096.00, size=312961, txCount=131
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100189, BaseFeePerGas=11562746707.00, burntFees=181747704398108192.00, txFees=302452254488256256.00, size=222605, txCount=143
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100190, BaseFeePerGas=11631968985.00, burntFees=179145164062759424.00, txFees=223317659619075008.00, size=187251, txCount=99
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100191, BaseFeePerGas=11670849229.00, burntFees=266856103386493920.00, txFees=429239846521463040.00, size=213841, txCount=151
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100192, BaseFeePerGas=12435793936.00, burntFees=194072254017579840.00, txFees=286741890973477408.00, size=119257, txCount=132
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100193, BaseFeePerGas=12498588477.00, burntFees=251388896997287680.00, txFees=396414095243243136.00, size=309145, txCount=154
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100194, BaseFeePerGas=13031172392.00, burntFees=203606647657284928.00, txFees=248799495945277824.00, size=228458, txCount=130
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100195, BaseFeePerGas=13098997906.00, burntFees=206246682403496768.00, txFees=253119404284132512.00, size=131917, txCount=158
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100196, BaseFeePerGas=13180345521.00, burntFees=140264749361697728.00, txFees=160287144104117376.00, size=116318, txCount=108
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100197, BaseFeePerGas=12701675243.00, burntFees=280774735501020448.00, txFees=346670725441105408.00, size=396989, txCount=140
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100198, BaseFeePerGas=13453755300.00, burntFees=173779251198955200.00, txFees=194011483844039040.00, size=174310, txCount=113
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100199, BaseFeePerGas=13220196315.00, burntFees=172013553177309920.00, txFees=188843531140001024.00, size=125913, txCount=134
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100200, BaseFeePerGas=13001118053.00, burntFees=239665678452862496.00, txFees=270620198217436576.00, size=155473, txCount=134
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100201, BaseFeePerGas=13375144535.00, burntFees=223963531703308448.00, txFees=268814500418536096.00, size=240194, txCount=149
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100202, BaseFeePerGas=13569615974.00, burntFees=200914000236911648.00, txFees=233123736599102752.00, size=294856, txCount=129
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100203, BaseFeePerGas=13547697313.00, burntFees=187157116663652160.00, txFees=262355859003556704.00, size=181527, txCount=133
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100204, BaseFeePerGas=13413877788.00, burntFees=169904951403300544.00, txFees=216892464797019552.00, size=125554, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100205, BaseFeePerGas=13154401660.00, burntFees=218667302557592480.00, txFees=261870661404276672.00, size=335538, txCount=147
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100206, BaseFeePerGas=13335893040.00, burntFees=206124937191135104.00, txFees=310435254257773696.00, size=196666, txCount=139
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100207, BaseFeePerGas=13388294864.00, burntFees=177364582460133056.00, txFees=211875179455885952.00, size=225778, txCount=118
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100208, BaseFeePerGas=13192799051.00, burntFees=230993470573504896.00, txFees=293792979559166208.00, size=181869, txCount=147
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100209, BaseFeePerGas=13468644757.00, burntFees=166770927832979872.00, txFees=214287231737873504.00, size=151509, txCount=126
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100210, BaseFeePerGas=13174821895.00, burntFees=260508757189227072.00, txFees=319257675807474304.00, size=345382, txCount=154
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100211, BaseFeePerGas=13698875468.00, burntFees=206311694803806528.00, txFees=239773639446109984.00, size=140897, txCount=216
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100212, BaseFeePerGas=13705780157.00, burntFees=264684738048649248.00, txFees=288215847781179616.00, size=344684, txCount=115
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100213, BaseFeePerGas=14198263787.00, burntFees=184445754532639360.00, txFees=218531136607549888.00, size=193469, txCount=150
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100214, BaseFeePerGas=13962031214.00, burntFees=168066596421497248.00, txFees=188655246901375296.00, size=79681, txCount=138
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100215, BaseFeePerGas=13617333590.00, burntFees=198774002283930304.00, txFees=334103041807021888.00, size=207380, txCount=138
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100216, BaseFeePerGas=13571616911.00, burntFees=104913945939092928.00, txFees=169106434343432864.00, size=59309, txCount=109
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100217, BaseFeePerGas=12749447680.00, burntFees=207995713398497280.00, txFees=258338432173813824.00, size=155677, txCount=171
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100218, BaseFeePerGas=12889064331.00, burntFees=142762833911911360.00, txFees=208750115868640736.00, size=158675, txCount=111
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100219, BaseFeePerGas=12467621573.00, burntFees=176895901149270944.00, txFees=200382614528873920.00, size=113965, txCount=161
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100220, BaseFeePerGas=12383301386.00, burntFees=206476418217256320.00, txFees=224924630245842688.00, size=440716, txCount=129
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100221, BaseFeePerGas=12556025531.00, burntFees=154843606393781152.00, txFees=180866214774233792.00, size=172355, txCount=115
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100222, BaseFeePerGas=12276885727.00, burntFees=141651431854383888.00, txFees=187232213311924384.00, size=126554, txCount=131
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100223, BaseFeePerGas=11922703610.00, burntFees=148078154662547680.00, txFees=258011271086836672.00, size=145721, txCount=107
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100224, BaseFeePerGas=11666350281.00, burntFees=154746786676787968.00, txFees=208127344497679168.00, size=240080, txCount=124
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100225, BaseFeePerGas=11497613052.00, burntFees=163943567694649952.00, txFees=202475548826914144.00, size=139496, txCount=129
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100226, BaseFeePerGas=11426607818.00, burntFees=126569963813226944.00, txFees=168607504939816928.00, size=109887, txCount=116
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100227, BaseFeePerGas=11053031540.00, burntFees=151995829540499232.00, txFees=208716277159827488.00, size=140024, txCount=155
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100228, BaseFeePerGas=10938034511.00, burntFees=141840450094086000.00, txFees=183477090144776960.00, size=163601, txCount=142
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100229, BaseFeePerGas=10752783948.00, burntFees=168798955119487520.00, txFees=226703714720840864.00, size=383267, txCount=118
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100230, BaseFeePerGas=10815343913.00, burntFees=235327001633655712.00, txFees=272127735172856160.00, size=133439, txCount=152
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100231, BaseFeePerGas=11424484270.00, burntFees=126287368720038464.00, txFees=156196161330312000.00, size=102659, txCount=108
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100232, BaseFeePerGas=11048818476.00, burntFees=103237276098121760.00, txFees=118840710208547888.00, size=114441, txCount=107
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100233, BaseFeePerGas=10528026801.00, burntFees=178881408591040576.00, txFees=222146818847599968.00, size=245575, txCount=145
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100234, BaseFeePerGas=10702701855.00, burntFees=107684560443865632.00, txFees=143440492773453456.00, size=215814, txCount=100
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100235, BaseFeePerGas=10262235461.00, burntFees=162749130829769216.00, txFees=191049056096913504.00, size=126900, txCount=126
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100236, BaseFeePerGas=10335698785.00, burntFees=150516052781475776.00, txFees=178999920483355328.00, size=135312, txCount=128
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100237, BaseFeePerGas=10298036877.00, burntFees=198086940928140800.00, txFees=229444333385896512.00, size=441949, txCount=112
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100238, BaseFeePerGas=10661506775.00, burntFees=191426479901569440.00, txFees=230227728059244224.00, size=373158, txCount=99
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100239, BaseFeePerGas=10925598402.00, burntFees=111999106787585344.00, txFees=149075988176356608.00, size=135376, txCount=106
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100240, BaseFeePerGas=10493225363.00, burntFees=105668321909538368.00, txFees=137423297542607312.00, size=86998, txCount=130
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100241, BaseFeePerGas=10062141542.00, burntFees=131372396621496992.00, txFees=147574286010797760.00, size=178693, txCount=131
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100242, BaseFeePerGas=9900213946.00, burntFees=158204953547024544.00, txFees=185347449904365824.00, size=270340, txCount=145
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100243, BaseFeePerGas=9983640404.00, burntFees=137388329939023776.00, txFees=165382065702719424.00, size=194212, txCount=131
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100244, BaseFeePerGas=9881708303.00, burntFees=118692805250863600.00, txFees=130070732148698528.00, size=64836, txCount=105
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100245, BaseFeePerGas=9635603388.00, burntFees=140264861840499168.00, txFees=155497190522989536.00, size=135314, txCount=133
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100246, BaseFeePerGas=9600026814.00, burntFees=167925637035984864.00, txFees=202941076294532032.00, size=353317, txCount=119
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100247, BaseFeePerGas=9799403770.00, burntFees=130373266834449088.00, txFees=148427322378331808.00, size=241802, txCount=128
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100248, BaseFeePerGas=9660922190.00, burntFees=105503984655722048.00, txFees=119739719231979712.00, size=148418, txCount=113
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100249, BaseFeePerGas=9332506789.00, burntFees=168504718849984352.00, txFees=225727153535634336.00, size=211030, txCount=149
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100250, BaseFeePerGas=9570149430.00, burntFees=94404097852223184.00, txFees=228525308373921984.00, size=109101, txCount=109
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100251, BaseFeePerGas=9160581567.00, burntFees=196367417345815712.00, txFees=234594122057464832.00, size=210950, txCount=147
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100252, BaseFeePerGas=9651904015.00, burntFees=111166509081755600.00, txFees=141742933258222128.00, size=237894, txCount=92
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100253, BaseFeePerGas=9371803589.00, burntFees=148241314810084192.00, txFees=170783564483923488.00, size=226644, txCount=133
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100254, BaseFeePerGas=9435672430.00, burntFees=127963400238378656.00, txFees=215948264768839072.00, size=122952, txCount=113
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100255, BaseFeePerGas=9322575045.00, burntFees=146562682087406976.00, txFees=177665963587093952.00, size=338246, txCount=122
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100256, BaseFeePerGas=9378608848.00, burntFees=187142655431979296.00, txFees=233837300301698848.00, size=148797, txCount=173
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100257, BaseFeePerGas=9765804870.00, burntFees=127843780452584944.00, txFees=154639483426876224.00, size=232966, txCount=116
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100258, BaseFeePerGas=9610444099.00, burntFees=165681903527281824.00, txFees=208106342621588928.00, size=308354, txCount=151
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100259, BaseFeePerGas=9789821116.00, burntFees=120558817785237472.00, txFees=146576164209049120.00, size=197173, txCount=121
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100260, BaseFeePerGas=9570750292.00, burntFees=137805347729889440.00, txFees=175107539938374208.00, size=266632, txCount=142
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100261, BaseFeePerGas=9522784404.00, burntFees=122959687301599424.00, txFees=168674074484377440.00, size=233866, txCount=111
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100262, BaseFeePerGas=9357100415.00, burntFees=130743938254469664.00, txFees=163154902135598080.00, size=119750, txCount=117
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100263, BaseFeePerGas=9276995682.00, burntFees=149898215741514176.00, txFees=177658341633503680.00, size=210419, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100264, BaseFeePerGas=9366523019.00, burntFees=193702224994135136.00, txFees=224221624244010176.00, size=136697, txCount=137
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100265, BaseFeePerGas=9809892849.00, burntFees=162725403871212928.00, txFees=194251281183149504.00, size=280892, txCount=132
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100266, BaseFeePerGas=9941026792.00, burntFees=125204309783363152.00, txFees=214039991991006784.00, size=242363, txCount=114
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100267, BaseFeePerGas=9741768666.00, burntFees=86370111838472032.00, txFees=112140324720528368.00, size=104682, txCount=84
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100268, BaseFeePerGas=9243798515.00, burntFees=113115669143166368.00, txFees=133586888203604848.00, size=158996, txCount=114
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100269, BaseFeePerGas=9030954277.00, burntFees=191552699325986912.00, txFees=240622752092063616.00, size=317099, txCount=138
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100270, BaseFeePerGas=9498357486.00, burntFees=72100046519511424.00, txFees=81665446931090432.00, size=105368, txCount=83
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100271, BaseFeePerGas=8911896522.00, burntFees=186642579635760800.00, txFees=345855509640830144.00, size=272586, txCount=203
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100272, BaseFeePerGas=9353264287.00, burntFees=93127253689272848.00, txFees=115079149525872960.00, size=108437, txCount=113
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100273, BaseFeePerGas=8960166699.00, burntFees=154756531640615488.00, txFees=201006049631172448.00, size=266057, txCount=149
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100274, BaseFeePerGas=9129783625.00, burntFees=117742400596350496.00, txFees=150599730301747392.00, size=219542, txCount=111
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100275, BaseFeePerGas=8969747344.00, burntFees=105809615320090944.00, txFees=143551073901880400.00, size=107783, txCount=109
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100276, BaseFeePerGas=8730275721.00, burntFees=133698445606242016.00, txFees=163956381847251936.00, size=222996, txCount=141
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100277, BaseFeePerGas=8753144969.00, burntFees=128656578279621888.00, txFees=147364188077433312.00, size=190945, txCount=138
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100278, BaseFeePerGas=8731140001.00, burntFees=261271899405224160.00, txFees=291603748197251776.00, size=39131, txCount=100
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100279, BaseFeePerGas=9817013329.00, burntFees=163431645047486208.00, txFees=185379442001390656.00, size=284171, txCount=142
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100280, BaseFeePerGas=9953148308.00, burntFees=116324335373774528.00, txFees=130868232355921584.00, size=116936, txCount=139
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100281, BaseFeePerGas=9678375136.00, burntFees=132653813037669152.00, txFees=143457297464856864.00, size=189560, txCount=161
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100282, BaseFeePerGas=9574026686.00, burntFees=104971926351708640.00, txFees=131933194625196048.00, size=120915, txCount=119
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100283, BaseFeePerGas=9252039404.00, burntFees=151735694471175168.00, txFees=181990103288603200.00, size=170632, txCount=150
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100284, BaseFeePerGas=9359998599.00, burntFees=101306475316496464.00, txFees=117970747130625904.00, size=126872, txCount=113
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100285, BaseFeePerGas=9034219402.00, burntFees=156986130868133280.00, txFees=179878281968164032.00, size=322189, txCount=114
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100286, BaseFeePerGas=9213159733.00, burntFees=102233311040289456.00, txFees=109961355815237696.00, size=319861, txCount=90
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100287, BaseFeePerGas=8913459026.00, burntFees=142319720633943680.00, txFees=209584077409358400.00, size=133967, txCount=191
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100288, BaseFeePerGas=8985274319.00, burntFees=134361137794228752.00, txFees=157126891055661344.00, size=311654, txCount=147
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100289, BaseFeePerGas=8981791178.00, burntFees=89020490395634800.00, txFees=101941283648674160.00, size=161343, txCount=112
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100290, BaseFeePerGas=8600904701.00, burntFees=219783080662528288.00, txFees=242693870168500256.00, size=146166, txCount=230
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100291, BaseFeePerGas=9357317285.00, burntFees=68924941744456792.00, txFees=93942368879068032.00, size=87444, txCount=77
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100292, BaseFeePerGas=8762027139.00, burntFees=262805262917938752.00, txFees=290967106342930560.00, size=91440, txCount=68
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100293, BaseFeePerGas=9856817604.00, burntFees=295541318934112960.00, txFees=332405148279452544.00, size=200195, txCount=174
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100294, BaseFeePerGas=11087559727.00, burntFees=208226688973042944.00, txFees=268830083086879456.00, size=260622, txCount=158
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100295, BaseFeePerGas=11436837169.00, burntFees=130314593639016336.00, txFees=148401908726360576.00, size=119069, txCount=116
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100296, BaseFeePerGas=11093187470.00, burntFees=74234212807618784.00, txFees=84956111591034736.00, size=88245, txCount=75
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100297, BaseFeePerGas=10325157477.00, burntFees=167735074257958560.00, txFees=246358292462899520.00, size=210859, txCount=163
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100298, BaseFeePerGas=10432305077.00, burntFees=142965070333478624.00, txFees=197099837081002528.00, size=284906, txCount=108
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100299, BaseFeePerGas=10319642529.00, burntFees=146210779918662848.00, txFees=168562371434720192.00, size=211406, txCount=104
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100300, BaseFeePerGas=10249301373.00, burntFees=155832499680476224.00, txFees=292934513353533824.00, size=147112, txCount=153
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100301, BaseFeePerGas=10266744077.00, burntFees=98859608059281472.00, txFees=133866789388584576.00, size=218304, txCount=97
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100302, BaseFeePerGas=9807231135.00, burntFees=144491534890630016.00, txFees=167420155658148320.00, size=192898, txCount=140
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100303, BaseFeePerGas=9785423368.00, burntFees=151940362715536768.00, txFees=190466264622252672.00, size=186157, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100304, BaseFeePerGas=9828415136.00, burntFees=127874275785916256.00, txFees=145811246096381280.00, size=231084, txCount=112
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100305, BaseFeePerGas=9665482209.00, burntFees=158179975482761248.00, txFees=183174504524172512.00, size=259812, txCount=154
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100306, BaseFeePerGas=9775463395.00, burntFees=141501435818621776.00, txFees=159873188855001920.00, size=309290, txCount=88
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100307, BaseFeePerGas=9732709103.00, burntFees=122874829531992416.00, txFees=138439197202949840.00, size=112414, txCount=112
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100308, BaseFeePerGas=9540077378.00, burntFees=140349210869387360.00, txFees=186469904335652096.00, size=264527, txCount=123
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100309, BaseFeePerGas=9517144463.00, burntFees=123775374587857904.00, txFees=228702899006465504.00, size=185611, txCount=133
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100310, BaseFeePerGas=9358962861.00, burntFees=112449866721264368.00, txFees=131132706887508704.00, size=121224, txCount=115
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100311, BaseFeePerGas=9126174727.00, burntFees=125054302194105952.00, txFees=231717435547319648.00, size=149568, txCount=138
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100312, BaseFeePerGas=9028540730.00, burntFees=176278339366573184.00, txFees=212244461748247232.00, size=342644, txCount=153
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100313, BaseFeePerGas=9368960671.00, burntFees=116739517249142384.00, txFees=129904665897334992.00, size=363718, txCount=98
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100314, BaseFeePerGas=9170669898.00, burntFees=157329298251798208.00, txFees=222435290413842368.00, size=131059, txCount=135
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100315, BaseFeePerGas=9335413646.00, burntFees=206913291425997280.00, txFees=275765150299305984.00, size=293052, txCount=222
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100316, BaseFeePerGas=9892764368.00, burntFees=73197612191855008.00, txFees=77404432961586960.00, size=124672, txCount=80
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100317, BaseFeePerGas=9266148924.00, burntFees=134241405177473808.00, txFees=201662477568532416.00, size=245913, txCount=139
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100318, BaseFeePerGas=9226558685.00, burntFees=95911673725227504.00, txFees=126072009768496496.00, size=49763, txCount=124
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100319, BaseFeePerGas=8872502798.00, burntFees=230356559459401248.00, txFees=332602263767260480.00, size=347382, txCount=187
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100320, BaseFeePerGas=9684954366.00, burntFees=130954752116557456.00, txFees=164128148493829792.00, size=308208, txCount=102
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100321, BaseFeePerGas=9565625690.00, burntFees=109888004367207696.00, txFees=146451845942079584.00, size=52355, txCount=125
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100322, BaseFeePerGas=9285655849.00, burntFees=109085034217706352.00, txFees=182109520574264160.00, size=164794, txCount=117
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100323, BaseFeePerGas=9033990820.00, burntFees=87866808043070896.00, txFees=103908285296211168.00, size=115545, txCount=106
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100324, BaseFeePerGas=8636965368.00, burntFees=168166707880942720.00, txFees=189630487082202880.00, size=358551, txCount=164
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100325, BaseFeePerGas=8958733929.00, burntFees=89642319040122272.00, txFees=114130774410478800.00, size=106795, txCount=97
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100326, BaseFeePerGas=8586641716.00, burntFees=118664563509995440.00, txFees=141617809900837200.00, size=218408, txCount=137
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100327, BaseFeePerGas=8502183788.00, burntFees=91025544433506960.00, txFees=103917063260825936.00, size=94083, txCount=101
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100328, BaseFeePerGas=8197957019.00, burntFees=245797254821637152.00, txFees=353589065185469248.00, size=133861, txCount=129
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100329, BaseFeePerGas=9221522848.00, burntFees=241510927224246464.00, txFees=292384486138631296.00, size=350190, txCount=444
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100330, BaseFeePerGas=10081423552.00, burntFees=98828336220185728.00, txFees=108129861734792896.00, size=45114, txCount=115
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100331, BaseFeePerGas=9644815077.00, burntFees=165717444128575840.00, txFees=186583470734228576.00, size=119743, txCount=113
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100332, BaseFeePerGas=9820191893.00, burntFees=132826138089985360.00, txFees=159994100018095616.00, size=284689, txCount=138
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100333, BaseFeePerGas=9699552391.00, burntFees=78361936901354896.00, txFees=90508317997194256.00, size=87054, txCount=89
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100334, BaseFeePerGas=9140124483.00, burntFees=151472473664019168.00, txFees=191173850918805152.00, size=219005, txCount=197
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100335, BaseFeePerGas=9259879536.00, burntFees=97310351706230304.00, txFees=120372867212772624.00, size=99975, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100336, BaseFeePerGas=8913314192.00, burntFees=158743585464975296.00, txFees=187626259854965408.00, size=301653, txCount=155
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100337, BaseFeePerGas=9122013130.00, burntFees=122051103523338592.00, txFees=162396194345171904.00, size=192699, txCount=114
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100338, BaseFeePerGas=8998854019.00, burntFees=127639052493736544.00, txFees=160830982613400384.00, size=128574, txCount=139
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100339, BaseFeePerGas=8937656038.00, burntFees=122246193671742960.00, txFees=140432248948363584.00, size=343534, txCount=123
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100340, BaseFeePerGas=8839167314.00, burntFees=77126233950812832.00, txFees=83218995653912192.00, size=105909, txCount=121
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100341, BaseFeePerGas=8376990017.00, burntFees=229833058322075968.00, txFees=277660654499287456.00, size=232629, txCount=170
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100342, BaseFeePerGas=9245141750.00, burntFees=104368423706033504.00, txFees=177895001691605792.00, size=204903, txCount=102
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100343, BaseFeePerGas=8959235896.00, burntFees=106292464262502960.00, txFees=127755945786863904.00, size=227252, txCount=125
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100344, BaseFeePerGas=8725101945.00, burntFees=130667405931582240.00, txFees=156769249525512000.00, size=273716, txCount=144
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100345, BaseFeePerGas=8723359252.00, burntFees=90423969252515456.00, txFees=113253578545094896.00, size=111043, txCount=121
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100346, BaseFeePerGas=8386472423.00, burntFees=251526049374507968.00, txFees=284930592149726272.00, size=120804, txCount=129
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100347, BaseFeePerGas=9434213781.00, burntFees=152038685438262048.00, txFees=186521774125213824.00, size=200570, txCount=129
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100348, BaseFeePerGas=9521926103.00, burntFees=142012348293963344.00, txFees=191687949439987104.00, size=301126, txCount=99
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100349, BaseFeePerGas=9515121576.00, burntFees=143406964530252480.00, txFees=164528086319300032.00, size=231926, txCount=127
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100350, BaseFeePerGas=9520789416.00, burntFees=92291723965826272.00, txFees=119624080771969248.00, size=102997, txCount=100
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100351, BaseFeePerGas=9099788439.00, burntFees=63937042727563072.00, txFees=79718260220154144.00, size=28347, txCount=60
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100352, BaseFeePerGas=8495123574.00, burntFees=254755325193889504.00, txFees=332756521840351104.00, size=276466, txCount=173
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100353, BaseFeePerGas=9556194170.00, burntFees=173286883846316544.00, txFees=234860366340287872.00, size=356460, txCount=126
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100354, BaseFeePerGas=9805727264.00, burntFees=95891756219563712.00, txFees=116783736498251840.00, size=73913, txCount=104
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100355, BaseFeePerGas=9379109325.00, burntFees=192655468662313728.00, txFees=263905080198334176.00, size=122193, txCount=140
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100356, BaseFeePerGas=9812182898.00, burntFees=132149910163655920.00, txFees=153819891566524768.00, size=301855, txCount=104
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100357, BaseFeePerGas=9686909288.00, burntFees=138475676004713888.00, txFees=190037439184536992.00, size=263017, txCount=136
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100358, BaseFeePerGas=9630009594.00, burntFees=108729414502841488.00, txFees=130834761307201392.00, size=59033, txCount=117
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100359, BaseFeePerGas=9332336849.00, burntFees=133029587422745504.00, txFees=191221716147107584.00, size=146826, txCount=148
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100360, BaseFeePerGas=9274374639.00, burntFees=121654253635924192.00, txFees=141609209159404800.00, size=148488, txCount=109
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100361, BaseFeePerGas=9128863257.00, burntFees=183675659095945504.00, txFees=232999097624432416.00, size=365004, txCount=150
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100362, BaseFeePerGas=9518385842.00, burntFees=127569357184608432.00, txFees=148545506387992128.00, size=221666, txCount=130
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100363, BaseFeePerGas=9391665589.00, burntFees=138268364617435408.00, txFees=202069439400259328.00, size=120044, txCount=119
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100364, BaseFeePerGas=9369943763.00, burntFees=112854123196444240.00, txFees=129801123237955696.00, size=123776, txCount=123
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100365, BaseFeePerGas=9139151820.00, burntFees=141742459645097936.00, txFees=203920172399231968.00, size=294183, txCount=133
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100366, BaseFeePerGas=9177945006.00, burntFees=118884821893339904.00, txFees=157623680982313824.00, size=114970, txCount=127
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100367, BaseFeePerGas=9021408730.00, burntFees=147000201584814336.00, txFees=160918906412579584.00, size=212871, txCount=131
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100368, BaseFeePerGas=9118734318.00, burntFees=111479855375576064.00, txFees=125271399442155328.00, size=184664, txCount=119
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100369, BaseFeePerGas=8907891324.00, burntFees=120687131432710832.00, txFees=141210551314089088.00, size=121068, txCount=164
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100370, BaseFeePerGas=8800131004.00, burntFees=149954302709208032.00, txFees=219113032674784768.00, size=300045, txCount=140
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100371, BaseFeePerGas=8949733817.00, burntFees=113455623452634112.00, txFees=137167123649913056.00, size=126677, txCount=125
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100372, BaseFeePerGas=8776480619.00, burntFees=136495223084687552.00, txFees=149792482483762048.00, size=325124, txCount=120
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100373, BaseFeePerGas=8816880733.00, burntFees=145566524564215328.00, txFees=168200954720702784.00, size=327741, txCount=119
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100374, BaseFeePerGas=8929010758.00, burntFees=127137210822579584.00, txFees=148949433566725248.00, size=128755, txCount=135
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100375, BaseFeePerGas=8872362159.00, burntFees=110877732453779824.00, txFees=135607568989577952.00, size=226228, txCount=111
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100376, BaseFeePerGas=8687297993.00, burntFees=154124098879978784.00, txFees=213602423075608896.00, size=365641, txCount=154
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100377, BaseFeePerGas=8885753234.00, burntFees=144066734248826112.00, txFees=188616227515842464.00, size=270338, txCount=139
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100378, BaseFeePerGas=8975590198.00, burntFees=110601288362115696.00, txFees=193356572201785408.00, size=260055, txCount=106
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100379, BaseFeePerGas=8776219755.00, burntFees=114161584370005552.00, txFees=131455666597947744.00, size=117506, txCount=122
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100380, BaseFeePerGas=8630539710.00, burntFees=123982570558546432.00, txFees=195554133601202912.00, size=181498, txCount=130
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100381, BaseFeePerGas=8584910335.00, burntFees=163496294969775360.00, txFees=177194001133779264.00, size=329398, txCount=116
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100382, BaseFeePerGas=8874265667.00, burntFees=113350817879277664.00, txFees=128034817199647824.00, size=110985, txCount=107
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100383, BaseFeePerGas=8709572608.00, burntFees=126216565620789248.00, txFees=147705642982691424.00, size=322967, txCount=124
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100384, BaseFeePerGas=8672680746.00, burntFees=120131614724429088.00, txFees=171000986125231648.00, size=105350, txCount=143
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100385, BaseFeePerGas=8589692443.00, burntFees=110824684332670368.00, txFees=187701088381272576.00, size=59453, txCount=126
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100386, BaseFeePerGas=8439519924.00, burntFees=243979963495859040.00, txFees=260295137486648128.00, size=184167, txCount=137
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100387, BaseFeePerGas=9417746295.00, burntFees=78218526788344800.00, txFees=99539883600577792.00, size=144532, txCount=79
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100388, BaseFeePerGas=8892349065.00, burntFees=97312986267723312.00, txFees=132205193131207168.00, size=166645, txCount=114
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100389, BaseFeePerGas=8591746985.00, burntFees=131931430002866000.00, txFees=154821021412768960.00, size=133844, txCount=157
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100390, BaseFeePerGas=8617207195.00, burntFees=258401960299801504.00, txFees=281365515406115584.00, size=36374, txCount=95
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100391, BaseFeePerGas=9693405964.00, burntFees=132151744758760272.00, txFees=150082671607769184.00, size=138694, txCount=97
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100392, BaseFeePerGas=9582994759.00, burntFees=150095878667621600.00, txFees=187855670108203776.00, size=346389, txCount=127
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100393, BaseFeePerGas=9635919403.00, burntFees=119673522651704768.00, txFees=136177239429779776.00, size=222951, txCount=102
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100394, BaseFeePerGas=9428708834.00, burntFees=114834272061685312.00, txFees=279011250849753344.00, size=107487, txCount=144
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100395, BaseFeePerGas=9207072497.00, burntFees=117250392562100544.00, txFees=128489307656955168.00, size=224589, txCount=103
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100396, BaseFeePerGas=9033275040.00, burntFees=127444452344908320.00, txFees=145524579389590080.00, size=258076, txCount=125
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100397, BaseFeePerGas=8966152763.00, burntFees=87374011007881344.00, txFees=99794135675387120.00, size=212038, txCount=94
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100398, BaseFeePerGas=8573500427.00, burntFees=164937061229128992.00, txFees=185052129226225632.00, size=150555, txCount=128
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100399, BaseFeePerGas=8876288383.00, burntFees=113802911111019760.00, txFees=132462057290856688.00, size=125162, txCount=135
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100400, BaseFeePerGas=8715109928.00, burntFees=94443981703739744.00, txFees=103766422209282880.00, size=180793, txCount=107
#  on 2023-09-09  Volume=2081625742.00  → blockNumber=18100401, BaseFeePerGas=8412754368.00, burntFees=251719125515750208.00, txFees=274299715510018880.00, size=210486, txCount=156
# ...
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197583, BaseFeePerGas=7647975177.00, burntFees=58758100777086088.00, txFees=66959333960586376.00, size=70707, txCount=85
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197584, BaseFeePerGas=7181629120.00, burntFees=201613371739141440.00, txFees=218863196945229888.00, size=225924, txCount=214
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197585, BaseFeePerGas=7964036911.00, burntFees=73121645617608288.00, txFees=89970607613537952.00, size=98968, txCount=91
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197586, BaseFeePerGas=7577879344.00, burntFees=131394661058779216.00, txFees=174675072145168128.00, size=269122, txCount=120
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197587, BaseFeePerGas=7725599934.00, burntFees=117219067660194480.00, txFees=155619042367754592.00, size=112970, txCount=136
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197588, BaseFeePerGas=7736725506.00, burntFees=77336447419035104.00, txFees=160316618311632384.00, size=89321, txCount=115
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197589, BaseFeePerGas=7414105213.00, burntFees=127402575300201536.00, txFees=165491386556494496.00, size=247961, txCount=149
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197590, BaseFeePerGas=7549030188.00, burntFees=115988825698529616.00, txFees=131989492532170800.00, size=90290, txCount=133
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197591, BaseFeePerGas=7571974961.00, burntFees=108338197339346352.00, txFees=149858714792534400.00, size=143757, txCount=110
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197592, BaseFeePerGas=7528296403.00, burntFees=74829361586830048.00, txFees=119481477082968672.00, size=150050, txCount=135
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197593, BaseFeePerGas=7210837366.00, burntFees=175791994628482752.00, txFees=214475444581540384.00, size=106708, txCount=165
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197594, BaseFeePerGas=7774415983.00, burntFees=106708834992904128.00, txFees=180977982273155200.00, size=98684, txCount=125
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197595, BaseFeePerGas=7691854277.00, burntFees=66588228638903456.00, txFees=87471695975069984.00, size=91795, txCount=99
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197596, BaseFeePerGas=7285274398.00, burntFees=137251218432096928.00, txFees=194347710424821088.00, size=275632, txCount=128
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197597, BaseFeePerGas=7518375251.00, burntFees=74450628220899744.00, txFees=138462801741321760.00, size=85460, txCount=121
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197598, BaseFeePerGas=7199000247.00, burntFees=126543882361761056.00, txFees=164056641597068096.00, size=131353, txCount=159
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197599, BaseFeePerGas=7354688361.00, burntFees=124820954017249744.00, txFees=168598330370046144.00, size=113265, txCount=121
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197600, BaseFeePerGas=7475527903.00, burntFees=77767557949569664.00, txFees=113750056338913136.00, size=97233, txCount=118
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197601, BaseFeePerGas=7189149899.00, burntFees=194660288303477536.00, txFees=251561646025350336.00, size=166860, txCount=168
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197602, BaseFeePerGas=7912675230.00, burntFees=51780222285435568.00, txFees=89138868600343104.00, size=113478, txCount=73
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197603, BaseFeePerGas=7355092679.00, burntFees=139295790748479792.00, txFees=203931274963563264.00, size=129119, txCount=187
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197604, BaseFeePerGas=7596504350.00, burntFees=76087924554365600.00, txFees=93538320765876048.00, size=168036, txCount=112
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197605, BaseFeePerGas=7281007345.00, burntFees=61201366397264208.00, txFees=69121091456467408.00, size=84401, txCount=104
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197606, BaseFeePerGas=6880892814.00, burntFees=206219875973083008.00, txFees=235799221930931104.00, size=130415, txCount=151
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197607, BaseFeePerGas=7739280178.00, burntFees=158465917638005600.00, txFees=174555257217861568.00, size=358030, txCount=166
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197608, BaseFeePerGas=8092419469.00, burntFees=76651818016180384.00, txFees=108224544570917520.00, size=48283, txCount=112
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197609, BaseFeePerGas=7719632186.00, burntFees=74684423023365280.00, txFees=88251350265721200.00, size=95483, txCount=119
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197610, BaseFeePerGas=7377048355.00, burntFees=112256271867245872.00, txFees=182120912667182496.00, size=233252, txCount=130
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197611, BaseFeePerGas=7390386242.00, burntFees=98465145960525216.00, txFees=114633708426287072.00, size=175449, txCount=113
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197612, BaseFeePerGas=7287130845.00, burntFees=146686016146324544.00, txFees=181137428446764576.00, size=507692, txCount=165
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197613, BaseFeePerGas=7598622957.00, burntFees=60784318101504400.00, txFees=85106781453479968.00, size=90470, txCount=97
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197614, BaseFeePerGas=7155331072.00, burntFees=195529210035306496.00, txFees=217935688936456992.00, size=124798, txCount=129
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197615, BaseFeePerGas=7890324771.00, burntFees=77447553802673440.00, txFees=90950653526658688.00, size=47773, txCount=178
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197616, BaseFeePerGas=7549430457.00, burntFees=106919397702838144.00, txFees=127577609745484224.00, size=234983, txCount=151
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197617, BaseFeePerGas=7496746631.00, burntFees=70841856704028080.00, txFees=86338608824492192.00, size=86531, txCount=120
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197618, BaseFeePerGas=7150002108.00, burntFees=212221271768155104.00, txFees=366009635959649280.00, size=51377, txCount=141
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197619, BaseFeePerGas=8024762442.00, burntFees=77441966851215744.00, txFees=97058523076748224.00, size=181386, txCount=102
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197620, BaseFeePerGas=7667016861.00, burntFees=76960395866256288.00, txFees=87895179738936656.00, size=97049, txCount=123
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197621, BaseFeePerGas=7349976386.00, burntFees=100959863636206880.00, txFees=134658310864883232.00, size=183996, txCount=123
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197622, BaseFeePerGas=7272561535.00, burntFees=65264221754743728.00, txFees=75637704884527920.00, size=95762, txCount=125
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197623, BaseFeePerGas=6907359858.00, burntFees=207182846704940160.00, txFees=295078283512940736.00, size=401925, txCount=152
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197624, BaseFeePerGas=7770463598.00, burntFees=93442863017216816.00, txFees=138813858409097920.00, size=160175, txCount=130
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197625, BaseFeePerGas=7577846174.00, burntFees=89093578608643312.00, txFees=109493152410450608.00, size=114071, txCount=110
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197626, BaseFeePerGas=7373061891.00, burntFees=74443188476455696.00, txFees=112440708246785552.00, size=151477, txCount=111
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197627, BaseFeePerGas=7071789059.00, burntFees=199510628285272960.00, txFees=210260343273623712.00, size=103851, txCount=112
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197628, BaseFeePerGas=7850403995.00, burntFees=84792323455650928.00, txFees=132238135134063488.00, size=113339, txCount=110
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197629, BaseFeePerGas=7575706192.00, burntFees=104823402650460336.00, txFees=320175478027695296.00, size=214405, txCount=116
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197630, BaseFeePerGas=7502271274.00, burntFees=97875771385837648.00, txFees=271176872831828896.00, size=103154, txCount=125
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197631, BaseFeePerGas=7380118793.00, burntFees=78687284138331168.00, txFees=1000147331368359680.00, size=169047, txCount=79
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197632, BaseFeePerGas=7113331312.00, burntFees=213122362945543136.00, txFees=255211940291028096.00, size=61581, txCount=162
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197633, BaseFeePerGas=8000184589.00, burntFees=63790431842542176.00, txFees=78278547684020224.00, size=92085, txCount=96
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197634, BaseFeePerGas=7531748448.00, burntFees=65563230041221920.00, txFees=83017707906887600.00, size=98798, txCount=89
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197635, BaseFeePerGas=7136640143.00, burntFees=200387820229018976.00, txFees=215857609638034336.00, size=117540, txCount=141
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197636, BaseFeePerGas=7914458627.00, burntFees=57599854910039224.00, txFees=62316091133341776.00, size=122310, txCount=77
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197637, BaseFeePerGas=7405150090.00, burntFees=164344236157641152.00, txFees=260950631839080416.00, size=160740, txCount=426
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197638, BaseFeePerGas=7850380334.00, burntFees=68426262254863864.00, txFees=78208331665756368.00, size=98895, txCount=101
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197639, BaseFeePerGas=7439302177.00, burntFees=95973619062237536.00, txFees=115300463317759680.00, size=91659, txCount=115
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197640, BaseFeePerGas=7309169564.00, burntFees=73507163456356896.00, txFees=90282760016650544.00, size=163124, txCount=132
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197641, BaseFeePerGas=7008083064.00, burntFees=210232463353135424.00, txFees=228210992466144512.00, size=96015, txCount=122
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197642, BaseFeePerGas=7884009875.00, burntFees=102549358402682624.00, txFees=108314693475210528.00, size=291170, txCount=118
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197643, BaseFeePerGas=7753086628.00, burntFees=111906137376154880.00, txFees=130254220331203200.00, size=310521, txCount=106
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197644, BaseFeePerGas=7716501945.00, burntFees=100726517040345488.00, txFees=112904972075869760.00, size=337811, txCount=100
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197645, BaseFeePerGas=7591326844.00, burntFees=71907537821572832.00, txFees=80993840554151888.00, size=122205, txCount=101
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197646, BaseFeePerGas=7241640471.00, burntFees=96703614045932512.00, txFees=132464425764112320.00, size=162463, txCount=144
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197647, BaseFeePerGas=7142298863.00, burntFees=196129176649017344.00, txFees=216217727759655072.00, size=99570, txCount=137
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197648, BaseFeePerGas=7883921310.00, burntFees=57717841017972360.00, txFees=68632199750515864.00, size=87102, txCount=97
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197649, BaseFeePerGas=7379413155.00, burntFees=120746739901834432.00, txFees=160094050468358400.00, size=177524, txCount=129
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197650, BaseFeePerGas=7464192913.00, burntFees=91420128564664224.00, txFees=117204651180381248.00, size=107310, txCount=130
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197651, BaseFeePerGas=7294493264.00, burntFees=80704019474477424.00, txFees=99848720079173424.00, size=132070, txCount=113
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197652, BaseFeePerGas=7055873124.00, burntFees=211536430985159808.00, txFees=228871614386411616.00, size=107277, txCount=128
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197653, BaseFeePerGas=7936695983.00, burntFees=95620956051864768.00, txFees=120592312492115360.00, size=144438, txCount=113
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197654, BaseFeePerGas=7741450286.00, burntFees=47756642966170560.00, txFees=70216929375948320.00, size=89750, txCount=61
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197655, BaseFeePerGas=7171741025.00, burntFees=214914236524085376.00, txFees=338046372878254208.00, size=1771747, txCount=92
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197656, BaseFeePerGas=8066225367.00, burntFees=234080069448308512.00, txFees=346158952931833344.00, size=1470903, txCount=177
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197657, BaseFeePerGas=9008614441.00, burntFees=85431816733214032.00, txFees=103329284427918656.00, size=159676, txCount=86
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197658, BaseFeePerGas=8594469442.00, burntFees=78923820766013552.00, txFees=96791031841261360.00, size=107579, txCount=93
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197659, BaseFeePerGas=8177859269.00, burntFees=103380972221353056.00, txFees=117854569912226768.00, size=320346, txCount=104
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197660, BaseFeePerGas=8017977076.00, burntFees=137812565029502976.00, txFees=163329298382682496.00, size=205822, txCount=127
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197661, BaseFeePerGas=8164169055.00, burntFees=100689374581346560.00, txFees=122858510943267104.00, size=114634, txCount=123
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197662, BaseFeePerGas=7982726045.00, burntFees=97044100640266288.00, txFees=156542302339679680.00, size=117947, txCount=138
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197663, BaseFeePerGas=7793586129.00, burntFees=114971457983761872.00, txFees=149947070318733728.00, size=133727, txCount=155
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197664, BaseFeePerGas=7777483347.00, burntFees=116909799722451664.00, txFees=143765904931925056.00, size=359116, txCount=133
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197665, BaseFeePerGas=7779546259.00, burntFees=113353302423724896.00, txFees=161099449196854656.00, size=316817, txCount=140
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197666, BaseFeePerGas=7751713831.00, burntFees=91459456075288736.00, txFees=161396603977758752.00, size=125067, txCount=124
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197667, BaseFeePerGas=7544911737.00, burntFees=100882667769487104.00, txFees=146371029721524000.00, size=172510, txCount=126
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197668, BaseFeePerGas=7442486668.00, burntFees=89937844483532512.00, txFees=151158159029365728.00, size=91992, txCount=137
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197669, BaseFeePerGas=7261657872.00, burntFees=217602752652457536.00, txFees=292421218807098816.00, size=114919, txCount=140
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197670, BaseFeePerGas=8167306910.00, burntFees=73731277868398912.00, txFees=125301961806331136.00, size=137040, txCount=98
#  on 2023-09-23  Volume=2101436678.00  → blockNumber=18197671, BaseFeePerGas=7760820862.00, burntFees=149402460377799584.00, txFees=175680112869496736.00, size=205748, txCount=222
#
# Gold‐standard table:
#    blockNumber  label
# 0     19415286      1
# 1     19415287      1
# 2     19415288      1
# 3     19415289      1
# 4     19415290      1
# … total rows: 89984

# %%
# collect extra “quantile” rows
quantile_rows = []

# how many nearest to grab around each quantile
K = 10000

for col in price_cols:
    for quantile_name, label in [('q25', 0), ('q75', 1)]:
        target = stats[col][quantile_name]
        idxs = nearest_k_idxs(merged[col], target, K)
        print(f"\n=== {col} {quantile_name} (label={label}) → {K} nearest to {target:.2f} ===")
        for idx in idxs:
            row = merged.loc[idx]
            print(
                f"  on {row['Date'].date()}  {col}={row[col]:.2f}  "
                f"blockNumber={int(row['blockNumber'])}"
            )
            quantile_rows.append({
                'blockNumber': int(row['blockNumber']),
                'label':       label,
            })

# turn into a DataFrame (and drop duplicates in case a block shows up twice)
quantile_df = pd.DataFrame(quantile_rows).drop_duplicates(subset='blockNumber')

# And now append to your existing gold_df:
gold_df = pd.concat([gold_df, quantile_df], ignore_index=True)  \
               .drop_duplicates(subset='blockNumber')     \
               .reset_index(drop=True)

print(f"\nAfter including quantiles, gold‐standard has {len(gold_df)} rows")
# Out:
# Streaming output truncated to the last 5000 lines.
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069869
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069870
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069871
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069872
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069873
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069874
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069875
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069876
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069877
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069878
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069879
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069880
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069881
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069882
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069883
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069884
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069885
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069886
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069887
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069888
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069889
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069890
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069891
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069892
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069893
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069894
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069895
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069896
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069897
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069898
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069899
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069900
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069901
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069902
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069903
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069904
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069905
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069906
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069907
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069908
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069909
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069910
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069911
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069912
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069913
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069914
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069915
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069916
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069917
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069918
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069919
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069920
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069921
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069922
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069923
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069924
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069925
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069926
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069927
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069928
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069929
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069930
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069931
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069932
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069933
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069934
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069935
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069936
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069937
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069938
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069939
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069940
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069941
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069942
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069943
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069944
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069945
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069946
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069947
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069948
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069949
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069950
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069951
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069952
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069953
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069954
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069955
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069956
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069957
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069958
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069959
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069960
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069961
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069962
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069963
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069964
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069965
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069966
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069967
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069968
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069969
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069970
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069971
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069972
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069973
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069974
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069975
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069976
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069977
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069978
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069979
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069980
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069981
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069982
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069983
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069984
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069985
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069986
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069987
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069988
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069989
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069990
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069991
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069992
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069993
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069994
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069995
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069996
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069997
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069998
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20069999
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070000
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070001
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070002
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070003
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070004
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070005
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070006
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070007
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070008
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070009
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070010
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070011
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070012
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070013
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070014
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070015
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070016
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070017
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070018
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070019
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070020
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070021
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070022
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070023
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070024
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070025
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070026
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070027
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070028
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070029
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070030
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070031
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070032
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070033
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070034
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070035
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070036
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070037
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070038
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070039
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070040
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070041
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070042
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070043
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070044
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070045
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070046
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070047
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070048
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070049
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070050
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070051
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070052
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070053
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070054
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070055
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070056
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070057
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070058
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070059
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070060
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070061
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070062
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070063
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070064
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070065
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070066
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070067
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070068
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070069
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070070
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070071
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070072
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070073
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070074
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070075
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070076
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070077
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070078
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070079
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070080
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070081
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070082
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070083
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070084
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070085
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070086
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070087
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070088
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070089
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070090
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070091
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070092
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070093
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070094
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070095
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070096
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070097
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070098
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070099
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070100
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070101
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070102
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070103
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070104
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070105
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070106
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070107
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070108
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070109
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070110
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070111
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070112
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070113
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070114
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070115
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070116
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070117
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070118
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070119
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070120
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070121
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070122
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070123
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070124
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070125
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070126
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070127
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070128
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070129
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070130
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070131
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070132
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070133
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070134
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070135
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070136
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070137
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070138
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070139
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070140
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070141
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070142
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070143
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070144
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070145
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070146
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070147
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070148
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070149
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070150
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070151
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070152
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070153
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070154
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070155
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070156
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070157
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070158
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070159
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070160
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070161
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070162
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070163
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070164
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070165
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070166
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070167
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070168
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070169
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070170
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070171
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070172
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070173
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070174
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070175
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070176
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070177
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070178
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070179
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070180
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070181
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070182
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070183
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070184
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070185
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070186
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070187
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070188
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070189
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070190
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070191
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070192
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070193
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070194
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070195
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070196
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070197
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070198
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070199
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070200
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070201
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070202
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070203
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070204
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070205
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070206
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070207
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070208
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070209
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070210
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070211
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070212
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070213
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070214
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070215
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070216
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070217
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070218
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070219
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070220
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070221
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070222
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070223
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070224
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070225
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070226
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070227
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070228
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070229
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070230
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070231
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070232
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070233
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070234
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070235
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070236
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070237
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070238
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070239
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070240
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070241
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070242
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070243
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070244
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070245
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070246
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070247
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070248
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070249
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070250
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070251
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070252
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070253
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070254
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070255
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070256
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070257
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070258
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070259
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070260
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070261
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070262
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070263
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070264
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070265
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070266
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070267
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070268
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070269
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070270
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070271
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070272
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070273
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070274
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070275
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070276
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070277
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070278
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070279
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070280
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070281
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070282
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070283
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070284
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070285
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070286
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070287
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070288
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070289
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070290
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070291
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070292
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070293
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070294
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070295
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070296
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070297
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070298
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070299
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070300
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070301
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070302
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070303
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070304
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070305
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070306
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070307
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070308
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070309
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070310
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070311
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070312
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070313
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070314
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070315
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070316
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070317
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070318
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070319
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070320
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070321
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070322
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070323
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070324
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070325
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070326
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070327
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070328
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070329
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070330
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070331
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070332
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070333
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070334
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070335
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070336
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070337
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070338
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070339
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070340
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070341
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070342
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070343
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070344
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070345
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070346
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070347
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070348
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070349
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070350
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070351
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070352
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070353
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070354
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070355
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070356
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070357
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070358
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070359
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070360
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070361
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070362
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070363
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070364
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070365
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070366
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070367
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070368
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070369
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070370
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070371
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070372
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070373
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070374
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070375
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070376
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070377
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070378
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070379
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070380
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070381
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070382
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070383
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070384
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070385
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070386
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070387
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070388
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070389
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070390
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070391
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070392
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070393
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070394
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070395
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070396
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070397
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070398
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070399
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070400
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070401
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070402
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070403
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070404
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070405
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070406
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070407
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070408
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070409
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070410
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070411
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070412
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070413
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070414
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070415
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070416
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070417
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070418
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070419
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070420
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070421
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070422
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070423
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070424
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070425
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070426
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070427
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070428
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070429
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070430
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070431
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070432
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070433
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070434
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070435
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070436
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070437
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070438
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070439
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070440
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070441
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070442
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070443
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070444
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070445
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070446
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070447
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070448
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070449
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070450
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070451
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070452
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070453
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070454
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070455
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070456
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070457
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070458
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070459
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070460
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070461
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070462
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070463
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070464
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070465
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070466
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070467
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070468
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070469
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070470
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070471
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070472
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070473
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070474
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070475
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070476
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070477
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070478
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070479
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070480
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070481
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070482
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070483
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070484
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070485
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070486
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070487
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070488
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070489
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070490
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070491
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070492
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070493
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070494
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070495
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070496
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070497
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070498
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070499
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070500
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070501
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070502
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070503
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070504
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070505
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070506
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070507
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070508
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070509
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070510
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070511
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070512
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070513
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070514
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070515
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070516
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070517
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070518
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070519
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070520
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070521
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070522
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070523
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070524
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070525
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070526
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070527
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070528
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070529
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070530
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070531
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070532
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070533
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070534
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070535
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070536
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070537
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070538
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070539
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070540
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070541
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070542
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070543
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070544
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070545
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070546
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070547
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070548
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070549
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070550
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070551
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070552
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070553
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070554
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070555
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070556
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070557
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070558
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070559
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070560
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070561
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070562
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070563
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070564
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070565
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070566
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070567
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070568
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070569
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070570
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070571
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070572
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070573
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070574
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070575
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070576
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070577
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070578
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070579
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070580
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070581
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070582
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070583
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070584
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070585
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070586
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070587
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070588
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070589
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070590
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070591
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070592
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070593
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070594
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070595
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070596
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070597
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070598
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070599
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070600
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070601
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070602
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070603
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070604
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070605
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070606
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070607
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070608
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070609
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070610
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070611
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070612
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070613
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070614
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070615
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070616
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070617
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070618
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070619
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070620
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070621
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070622
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070623
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070624
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070625
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070626
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070627
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070628
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070629
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070630
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070631
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070632
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070633
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070634
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070635
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070636
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070637
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070638
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070639
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070640
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070641
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070642
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070643
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070644
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070645
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070646
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070647
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070648
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070649
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070650
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070651
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070652
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070653
#   on 2024-06-11  Volume=19184721538.00  blockNumber=20070654
# ...
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790662
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790663
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790664
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790665
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790666
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790667
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790668
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790669
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790670
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790671
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790672
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790673
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790674
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790675
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790676
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790677
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790678
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790679
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790680
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790681
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790682
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790683
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790684
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790685
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790686
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790687
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790688
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790689
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790690
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790691
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790692
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790693
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790694
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790695
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790696
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790697
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790698
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790699
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790700
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790701
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790702
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790703
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790704
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790705
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790706
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790707
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790708
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790709
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790710
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790711
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790712
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790713
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790714
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790715
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790716
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790717
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790718
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790719
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790720
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790721
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790722
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790723
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790724
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790725
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790726
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790727
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790728
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790729
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790730
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790731
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790732
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790733
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790734
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790735
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790736
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790737
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790738
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790739
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790740
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790741
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790742
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790743
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790744
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790745
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790746
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790747
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790748
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790749
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790750
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790751
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790752
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790753
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790754
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790755
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790756
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790757
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790758
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790759
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790760
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790761
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790762
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790763
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790764
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790765
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790766
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790767
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790768
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790769
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790770
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790771
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790772
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790773
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790774
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790775
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790776
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790777
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790778
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790779
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790780
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790781
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790782
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790783
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790784
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790785
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790786
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790787
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790788
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790789
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790790
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790791
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790792
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790793
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790794
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790795
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790796
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790797
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790798
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790799
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790800
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790801
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790802
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790803
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790804
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790805
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790806
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790807
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790808
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790809
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790810
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790811
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790812
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790813
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790814
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790815
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790816
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790817
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790818
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790819
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790820
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790821
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790822
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790823
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790824
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790825
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790826
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790827
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790828
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790829
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790830
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790831
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790832
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790833
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790834
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790835
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790836
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790837
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790838
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790839
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790840
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790841
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790842
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790843
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790844
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790845
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790846
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790847
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790848
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790849
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790850
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790851
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790852
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790853
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790854
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790855
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790856
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790857
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790858
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790859
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790860
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790861
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790862
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790863
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790864
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790865
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790866
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790867
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790868
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790869
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790870
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790871
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790872
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790873
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790874
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790875
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790876
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790877
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790878
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790879
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790880
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790881
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790882
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790883
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790884
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790885
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790886
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790887
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790888
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790889
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790890
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790891
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790892
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790893
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790894
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790895
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790896
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790897
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790898
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790899
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790900
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790901
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790902
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790903
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790904
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790905
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790906
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790907
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790908
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790909
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790910
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790911
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790912
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790913
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790914
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790915
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790916
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790917
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790918
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790919
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790920
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790921
#   on 2024-09-20  Volume=19112788620.00  blockNumber=20790922
#
# After including quantiles, gold‐standard has 189984 rows

# %%
#flushing just for checkinkg purposes
del gold_df

# %%
gold_df.tail()
# Out:
#         blockNumber  label
# 189979     20790918      1
# 189980     20790919      1
# 189981     20790920      1
# 189982     20790921      1
# 189983     20790922      1

# %%
# 1) Join your gold labels back to the full merged DataFrame
gs = pd.merge(
    gold_df,               # has blockNumber + label
    merged,                # your full DataFrame with all the block details
    on="blockNumber",
    how="left"
)

# 2) Select the on-chain detail columns you care about
detail_cols = [
    "baseFeePerGas",
    "gasUsed",
    "burntFees",
    "txFees",
    "size",
    "transactionCount",
]

gs[detail_cols].describe().T
gs.groupby("label")[detail_cols].describe().T
# Out:
# label                              0             1
# baseFeePerGas    count  9.283100e+04  9.715300e+04
#                  mean   1.428974e+10  2.313435e+10
#                  std    1.715361e+10  3.615083e+10
#                  min    2.846667e+08  8.516682e+08
#                  25%    6.245305e+08  6.357145e+09
#                  50%    7.869164e+09  1.190522e+10
#                  75%    2.133233e+10  2.617890e+10
#                  max    1.273805e+11  8.255167e+11
# gasUsed          count  9.283100e+04  9.715300e+04
#                  mean   1.632978e+07  1.517703e+07
#                  std    7.285556e+06  6.042085e+06
#                  min    0.000000e+00  0.000000e+00
#                  25%    1.153457e+07  1.148540e+07
#                  50%    1.461038e+07  1.433783e+07
#                  75%    1.944393e+07  1.808698e+07
#                  max    3.603187e+07  3.214556e+07
# size             count  9.283100e+04  9.715300e+04
#                  mean   1.300280e+05  9.017549e+04
#                  std    1.072917e+05  7.269283e+04
#                  min    1.084000e+03  1.139000e+03
#                  25%    6.182900e+04  5.541900e+04
#                  50%    9.831600e+04  7.169300e+04
#                  75%    1.699175e+05  9.863800e+04
#                  max    2.307411e+06  1.273567e+06
# transactionCount count  9.283100e+04  9.715300e+04
#                  mean   1.502234e+02  1.666299e+02
#                  std    6.475091e+01  6.516874e+01
#                  min    0.000000e+00  0.000000e+00
#                  25%    1.140000e+02  1.290000e+02
#                  50%    1.380000e+02  1.580000e+02
#                  75%    1.710000e+02  1.940000e+02
#                  max    1.202000e+03  1.289000e+03

# %%
print(gs[detail_cols].dtypes)
# Out:
# baseFeePerGas         int64
# gasUsed               int64
# burntFees           float64
# txFees              float64
# size                  int64
# transactionCount      int64
# dtype: object

# %%
for col in ["burntFees", "txFees"]:
    gs[col] = pd.to_numeric(gs[col], errors="coerce")

# %%
gs.head()
# Out:
#    blockNumber  label   timestamp    size  transactionCount  \
# 0     19415286      1  1710201611  221168               295
# 1     19415287      1  1710201623   55344               216
# 2     19415288      1  1710201635   65526               258
# 3     19415289      1  1710201647   51864               147
# 4     19415290      1  1710201659  211122               194
#
#    internalTxCntSimple  internalTxCntAdvanced  erc20TxCnt  erc721TxCnt  \
# 0                  115                    763         271           25
# 1                   57                    562         159            1
# 2                   46                    633         183            0
# 3                   37                    459         128            2
# 4                   42                    536         156            0
#
#                                  minerAddress  ... baseFeePerGas  \
# 0  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5  ...   64830560569
# 1  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5  ...   68575964680
# 2  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97  ...   67430588917
# 3  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5  ...   67053733966
# 4  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5  ...   64424500062
#
#              burntFees            tipsFees       Date        Open        High  \
# 0  1421906901891525816   88821996065792881 2024-03-12  4066.69043  4092.28418
# 1   891194378590993000   31390226327687380 2024-03-12  4066.69043  4092.28418
# 2   966236239575458282   69011140234447996 2024-03-12  4066.69043  4092.28418
# 3   690297940952312268  260528242757654758 2024-03-12  4066.69043  4092.28418
# 4   995630912744162136   56002238179393252 2024-03-12  4066.69043  4092.28418
#
#            Low        Close    Adj Close       Volume
# 0  3831.889893  3980.273193  3980.273193  26917010932
# 1  3831.889893  3980.273193  3980.273193  26917010932
# 2  3831.889893  3980.273193  3980.273193  26917010932
# 3  3831.889893  3980.273193  3980.273193  26917010932
# 4  3831.889893  3980.273193  3980.273193  26917010932
#
# [5 rows x 27 columns]

# %%
print(gold_df["label"].value_counts())
# Out:
# label
# 1    97153
# 0    92831
# Name: count, dtype: int64

# %%
pip install snorkel
# Out:
# Collecting snorkel
#   Downloading snorkel-0.10.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting munkres>=1.0.6 (from snorkel)
#   Downloading munkres-1.1.4-py2.py3-none-any.whl.metadata (980 bytes)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from snorkel) (2.0.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from snorkel) (1.15.3)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from snorkel) (2.2.2)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.11/dist-packages (from snorkel) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.20.2 in /usr/local/lib/python3.11/dist-packages (from snorkel) (1.6.1)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from snorkel) (2.6.0+cpu)
# Collecting tensorboard>=2.13.0 (from snorkel)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from snorkel) (5.29.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.11/dist-packages (from snorkel) (3.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->snorkel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->snorkel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->snorkel) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.2->snorkel) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.2->snorkel) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->snorkel) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->snorkel) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard>=2.13.0->snorkel) (3.3.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->snorkel) (25.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->snorkel) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->snorkel) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.13.0->snorkel)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.13.0->snorkel)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.2.0->snorkel) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.2.0->snorkel) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.2.0->snorkel) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.2.0->snorkel) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.2.0->snorkel) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.2.0->snorkel) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.13.0->snorkel) (3.0.2)
# Downloading snorkel-0.10.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 3.0 MB/s eta 0:00:00
# Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 62.8 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 121.8 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 17.0 MB/s eta 0:00:00
# Installing collected packages: munkres, werkzeug, tensorboard-data-server, tensorboard, snorkel
# Successfully installed munkres-1.1.4 snorkel-0.10.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 werkzeug-3.1.3

# %%
#figure out the type for each data value in both df_tx and df_info
# convert the types correctly (if need be)
# then LSTM

ABSTAIN = -1
HIGH = 1
LOW = 0

from snorkel.labeling import labeling_function

tx_median = merged['transactionCount'].median()
hi_tx = merged['transactionCount'].quantile(0.75)  # 75th percentile
lo_tx = merged['transactionCount'].quantile(0.25)  # 25th percentile

@labeling_function()
def lf_tx_count(row):
    # High transaction count
    if row.transactionCount > hi_tx * 1.5:
        return 1
    # Low transaction count
    elif row.transactionCount < lo_tx * 0.5:
        return 0
    else:
        return -1


#coefficient of variance
mean_gas = merged['avgGasPrice'].mean()
std_gas = merged['avgGasPrice'].std()
cv_gas = std_gas / mean_gas
merged['cv_gas'] = cv_gas


@labeling_function()
def lf_fee_dispersion(row):
    # High gas fee dispersion
    if row.cv_gas > 0.5:
        return 1
    elif row.cv_gas < 0.1:
        return 0
    else:
        return -1

#have to convert to numeric
merged['txFees'] = pd.to_numeric(df_info['txFees'], errors='coerce')
threshold_high_value = merged['txFees'].quantile(0.75)
threshold_low_value = merged['txFees'].quantile(0.25)


@labeling_function()
def lf_tx_fees(row):
    # High volatility if transaction fee is unusually high
    if row.txFees > threshold_high_value:
        return 1  # HIGH volatility
    elif row.txFees < threshold_low_value:
        return 0  # LOW volatility
    else:
        return -1

@labeling_function()
def lf_whale_value(row):
    # High volatility if transaction fees are greater than a defined threshold
    if row.txFees > 1e9:  # 1 billion
        return 1
    elif row.txFees < 1e6:  # 1 million
        return 0
    else:
        return -1



@labeling_function()
def lf_gas_utilisation(row):
    gas_utilisation = row.gasUsed / row.gasLimit
    # High volatility if gas usage is greater than 90%
    if gas_utilisation > 0.9:
        return 1
    # gas usage is less than 50%
    elif gas_utilisation < 0.5:
        return 0
    else:
        return -1  # Abstain





# @labeling_function()
# def lf_base_fee_jump(row, prev_row):
#     # Calculate percentage change in base fee
#     fee_change = abs(row.baseFeePerGas - prev_row.baseFeePerGas) / prev_row.baseFeePerGas

#     # High volatility if the fee change is greater than 50%
#     if fee_change > 0.5:
#           return 1
#     # Low volatility if fee change is less than 10%
#     elif fee_change < 0.1:
#         return 0
#     else:
#         return -1



# Group by blockNumber and count unique minerAddress (senders) per block
# merged['unique_senders'] = df_info.groupby('blockNumber')['minerAddress'].transform(lambda x: x.nunique())

# @labeling_function()
# def lf_unique_senders(row):
#     # High volatility if there are more than 100 unique senders
#     if row.unique_senders > 100:
#         return 1
#     elif row.unique_senders < 10:
#         return 0
#     else:
#         return -1

# %%
# @labeling_function()
# def lf_base_fee_jump(row):
#     # Compare the baseFeePerGas of the current row with a predefined threshold
#     threshold = 0.2
#     mean_base_fee = merged['baseFeePerGas'].mean()

#     if abs(row.baseFeePerGas - mean_base_fee) / mean_base_fee > threshold:
#         return 1  # High volatility (base fee jump)
#     elif abs(row.baseFeePerGas - mean_base_fee) / mean_base_fee < threshold:
#         return 0
#     else:
#         return -1

# %%
import numpy as np

def custom_sample(df, sample_frac, head_frac, tail_frac, middle_frac):
    # Determine the number of rows for each portion
    total_rows = len(df)

    # Get head and tail portions based on fractions
    head_rows = int(total_rows * head_frac)
    tail_rows = int(total_rows * tail_frac)

    # Get random sample from the middle portion (the remaining portion after head and tail)
    middle_rows = int(total_rows * middle_frac)

    # Head: Get the first few rows
    head_sample = df.head(head_rows)

    # Tail: Get the last few rows
    tail_sample = df.tail(tail_rows)

    # Middle: Randomly sample from the middle portion of the DataFrame
    middle_start = head_rows
    middle_end = total_rows - tail_rows
    middle_sample = df.iloc[middle_start:middle_end].sample(n=middle_rows, random_state=42)

    # Combine the samples and shuffle them to ensure randomness
    # sampled_df = pd.concat([head_sample, tail_sample, middle_sample]).sample(frac=1, random_state=42).reset_index(drop=True)
    sampled_df = pd.concat([head_sample, middle_sample, tail_sample]).reset_index(drop=True)

    return sampled_df

df_sample = custom_sample(merged, sample_frac=0.3, head_frac=0.001, tail_frac=0.001, middle_frac=0.001)

# %%
from snorkel.labeling.model import LabelModel
from snorkel.labeling import PandasLFApplier

lfs = [lf_tx_count, lf_base_fee_jump, lf_gas_utilisation, lf_whale_value, lf_tx_fees, lf_fee_dispersion]

applier = PandasLFApplier(lfs)
L_train = applier.apply(df_sample)

# Train the label model and compute the training labels
label_model = LabelModel(cardinality=2, verbose=True)
label_model.fit(L_train, n_epochs=500, log_freq=50, seed=123)

# %%
df_sample["label"] = label_model.predict(L=L_train, tie_break_policy="abstain")

# %%
from snorkel.labeling import LFAnalysis

gold_arr = gold_df['label'].to_numpy()
lf_analysis = LFAnalysis(L=L_train, lfs=lfs)

# 2) Get a summary table as a pandas DataFrame
# summary_df = lf_analysis.lf_summary()

# print(summary_df)



LFAnalysis(L_train).lf_summary(gold_arr).sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-b59f118d5b23> in <cell line: 0>()
#       2
#       3 gold_arr = gold_df['label'].to_numpy()
# ----> 4 lf_analysis = LFAnalysis(L=L_train, lfs=lfs)
#       5
#       6 # 2) Get a summary table as a pandas DataFrame
#
# /usr/local/lib/python3.11/dist-packages/snorkel/labeling/analysis.py in __init__(self, L, lfs)
#      43         if lfs is not None:
#      44             if len(lfs) != self._L_sparse.shape[1]:
# ---> 45                 raise ValueError(
#      46                     f"Number of LFs ({len(lfs)}) and number of "
#      47                     f"LF matrix columns ({self._L_sparse.shape[1]}) are different"
#
# ValueError: Number of LFs (7) and number of LF matrix columns (6) are different

# %%
print( merged[['size', 'gasLimit', 'gasUsed', 'minGasPrice', 'maxGasPrice', 'avgGasPrice','txFees','baseFeePerGas','burntFees', 'tipsFees', 'transactionCount']].describe(percentiles=[.25, .5, .75]) )
# Out:
#                size      gasLimit       gasUsed   minGasPrice   maxGasPrice  \
# count  5.250000e+06  5.250000e+06  5.250000e+06  5.246737e+06  5.246737e+06
# mean   1.140609e+05  3.054562e+07  1.541771e+07  1.924039e+10  2.522663e+11
# std    1.040432e+05  1.709177e+06  6.127393e+06  2.148307e+10  6.353599e+12
# min    5.440000e+02  2.988296e+07  0.000000e+00  2.261364e+08  3.155464e+08
# 25%    5.762300e+04  3.000000e+07  1.157581e+07  5.289518e+09  4.187946e+10
# 50%    7.939400e+04  3.000000e+07  1.429089e+07  1.333743e+10  8.255203e+10
# 75%    1.418680e+05  3.000000e+07  1.806794e+07  2.615222e+10  1.812290e+11
# max    2.333167e+06  3.607034e+07  3.603448e+07  1.434392e+12  1.373127e+16
#
#         avgGasPrice        txFees  baseFeePerGas  transactionCount
# count  5.246737e+06  5.250000e+06   5.250000e+06      5.250000e+06
# mean   2.397270e+10  3.561753e+17   1.922234e+10      1.591432e+02
# std    1.687356e+11  4.769272e+17   2.146122e+10      6.410531e+01
# min    3.442325e+08  0.000000e+00   2.261364e+08      0.000000e+00
# 25%    7.795325e+09  1.048250e+17   5.269621e+09      1.240000e+02
# 50%    1.684976e+10  2.371106e+17   1.332509e+10      1.490000e+02
# 75%    3.127889e+10  4.578302e+17   2.613590e+10      1.820000e+02
# max    3.661806e+14  2.884560e+20   8.255167e+11      1.516000e+03

# %%
import numpy as np
import pandas as pd
# NEW LABELING FUNCTIONS ----------


#figure out the type for each data value in both df_tx and df_info
# convert the types correctly (if need be)
# then LSTM

ABSTAIN = -1
HIGH = 1
LOW = 0

from snorkel.labeling import labeling_function

# tx_median = merged['transactionCount'].median()
# tx_mean= merged['transactionCount'].mean()
# tx_std = merged["transactionCount"].std()
# hi_tx = merged['transactionCount'].quantile(0.75)  # 75th percentile
# lo_tx = merged['transactionCount'].quantile(0.25)  # 25th percentile
# #can be quite spread for both high and low

# @labeling_function()
# def lf_tx_count(row):
#   # mu=tx_mean, sigma=tx_std, k=1.0):
#     # z = (row.transactionCount - mu) / sigma
#     # if z > k:
#     #     return 1
#     # elif z < -k:
#     #     return 0
#     # else:
#     #     return -1

#     # High transaction count

#     if row.transactionCount > tx_median or row.transactionCount > tx_mean:
#         return 1

#     # Low transaction count
#     elif row.transactionCount < tx_median and row.transactionCount < tx_mean:
#       return 0
#     else:
#         return -1


tx_25, tx_75 = np.quantile(merged["transactionCount"], [0.25, 0.75])
iqr = tx_75 - tx_25
# we’ll say “high” if > median + 0.5*IQR, “low” if < median - 0.5*IQR
med = merged["transactionCount"].median()
lo_iqr = med - 0.5 * iqr
hi_iqr = med + 0.5 * iqr

# Z‐score thresholds
tx_mean, tx_std = merged["transactionCount"].mean(), merged["transactionCount"].std()
k_z = 1.5   # flag anything >1.5σ away

# Delta‐based thresholds
merged = merged.sort_values("blockNumber")
merged["delta_tx"] = merged["transactionCount"].diff() / merged["transactionCount"].shift()
p_lo, p_hi = merged["delta_tx"].quantile([0.25, 0.75])

# ——————————————————————————————————————————————
@labeling_function(name="lf_tx_count_improved")
def lf_tx_count_improved(row,
                         lo_iqr: float = lo_iqr,
                         hi_iqr: float = hi_iqr,
                         mu: float = tx_mean,
                         sigma: float = tx_std,
                         k_z: float = k_z,
                         lo_d: float = p_lo,
                         hi_d: float = p_hi) -> int:
    x = row.transactionCount

    # 1) IQR‐based
    if x >= hi_iqr:
        return 1
    if x <= lo_iqr:
        return 0

    # 2) Z‐score tails
    # z = (x - mu) / sigma
    # if z >= k_z:
    #     return 1
    # if z <= -k_z:
    #     return 0

    # 3) Sudden jump/drop from previous block
    d = row.delta_tx
    if d >= hi_d:
        return 1
    if d <= lo_d:
        return 0

    # otherwise, abstain
    return -1




# larger size means higher volatilitiy
large_size = merged['size'].quantile(0.75)  # 75th percentile
small_size = merged['size'].quantile(0.30)

@labeling_function()
def lf_size(row):
    if row.size > large_size:
        return 1
    # Low transaction count
    elif row.size < small_size:
        return 0
    else:
        return -1


#coefficient of variance
mean_gas = merged['avgGasPrice'].mean()
std_gas = merged['avgGasPrice'].std()
cv_gas = std_gas / mean_gas
merged['cv_gas'] = cv_gas


merged["dispersion"] = (
    merged["maxGasPrice"] - merged["minGasPrice"]
) / merged["avgGasPrice"]

p25_disp = merged["dispersion"].quantile(0.25)
p75_disp = merged["dispersion"].quantile(0.75)

@labeling_function()
def lf_fee_dispersion(row, lo=p25_disp, hi=p75_disp):
    if row.dispersion >= hi:
        return HIGH
    elif row.dispersion <= lo:
        return LOW
    return ABSTAIN



# @labeling_function()
# def lf_fee_dispersion(row):
#     # High gas fee dispersion
#     if row.cv_gas > 0.5:
#         return 1
#     elif row.cv_gas < 0.1:
#         return 0
#     else:
#         return -1

#have to convert to numeric
merged['txFees'] = pd.to_numeric(df_info['txFees'], errors='coerce')
threshold_high_value = merged['txFees'].quantile(0.75)
threshold_low_value = merged['txFees'].quantile(0.25)


@labeling_function()
def lf_tx_fees(row):
    # High volatility if transaction fee is unusually high
    if row.txFees > threshold_high_value:
        return 1  # HIGH volatility
    elif row.txFees < threshold_low_value:
        return 0  # LOW volatility
    else:
        return -1


# 50%
tx_fees_percentile = merged['txFees'].quantile(0.5)
@labeling_function()
def lf_whale_value(row):
    # High volatility if transaction fees are greater than a defined threshold
    if row.txFees > tx_fees_percentile:
        return 1
    elif row.txFees < tx_fees_percentile:  # 1 million
        return 0
    else:
        return -1



@labeling_function()
def lf_gas_utilisation(row):
    gas_utilisation = row.gasUsed / row.gasLimit
    # High volatility if gas usage is greater than 90%
    if gas_utilisation > 0.9:
        return 1
    # gas usage is less than 50%
    elif gas_utilisation < 0.5:
        return 0
    else:
        return -1  # Abstain


 # delta from the previous block
 #spikes and drops are seen more easily
merged = merged.sort_values("blockNumber")
merged["delta_baseFee"] = merged["baseFeePerGas"].diff() / merged["baseFeePerGas"].shift()
p75_delta   = merged["delta_baseFee"].quantile(0.75)
p25_delta   = merged["delta_baseFee"].quantile(0.25)

@labeling_function()
def lf_base_fee_jump_delta(row, lo=p25_delta, hi=p75_delta):
    if row.delta_baseFee >= hi:
        return 1
    elif row.delta_baseFee <= lo:
        return 0
    return -1

#0.47 and 0.53

# p25 = merged["baseFeePerGas"].quantile(0.25)
# p75 = merged["baseFeePerGas"].quantile(0.75)

# @labeling_function()
# def lf_base_fee_jump(row, low_cutoff: float = p25, high_cutoff: float = p75) -> int:
#     """
#     Label 1 if baseFeePerGas is in the top 25% (a big jump),
#     0 if it's in the bottom 25% (a big drop),
#     else abstain.
#     """
#     fee = row.baseFeePerGas
#     if fee >= high_cutoff:
#         return 1
#     elif fee <= low_cutoff:
#         return 0
#     else:
#         return -1

# %%
from snorkel.labeling import PandasLFApplier, LFAnalysis

# 1) Build df_dev = only those rows in merged_df that appear in gold_df
df_dev = merged[merged["blockNumber"].isin(gold_df["blockNumber"])].copy()

# 2) Merge in the true labels so they line up 1:1
df_dev = df_dev.merge(
    gold_df[["blockNumber", "label"]],
    on="blockNumber",
    how="inner",
)

# 3) Extract the gold‐label array
gold_arr = gold_df['label'].to_numpy()
# Y_dev = df_dev["label"].to_numpy()

# %%
lfs = [lf_tx_count, lf_base_fee_jump, lf_gas_utilisation, lf_whale_value, lf_tx_fees, lf_fee_dispersion]

# 4) Apply LFs to df_dev
applier = PandasLFApplier(lfs)
L_dev = applier.apply(df_dev)


# sanity check
print(L_dev.shape, gold_arr.shape)


summary_df = LFAnalysis(L_dev).lf_summary(gold_arr)
summary_df.sample(5)

# %%
lfs = [lf_tx_count_improved, lf_size, lf_fee_dispersion, lf_tx_fees, lf_whale_value, lf_gas_utilisation, lf_base_fee_jump_delta]

# 4) Apply LFs to df_dev
applier = PandasLFApplier(lfs)
L_dev = applier.apply(df_dev)


# sanity check
print(L_dev.shape, gold_arr.shape)


LFAnalysis(L_dev).lf_summary(gold_arr).sample(7)

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-192-1bd43f41771a> in <cell line: 0>()
# ----> 1 from snorkel.labeling import LabelModel, PandasLFApplier
#       2
#       3 lfs = [lf_tx_count, lf_size, lf_fee_dispersion, lf_tx_fees,
#       4        lf_whale_value, lf_gas_utilisation, lf_base_fee_jump_delta]
#       5
#
# ImportError: cannot import name 'LabelModel' from 'snorkel.labeling' (/usr/local/lib/python3.11/dist-packages/snorkel/labeling/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# print("L_train shape:", L_train.shape)
print("L_dev   shape:", L_dev.shape)
# Out:
# L_dev   shape: (189984, 7)

# %%
from snorkel.labeling.model import LabelModel
from snorkel.labeling import PandasLFApplier

label_model = LabelModel(cardinality=2, verbose=True)
label_model.fit(L_train=L_dev, n_epochs=500, log_freq=50, seed=123)

# merged["label"] = label_model.predict(L=L_train, tie_break_policy="abstain")

# preds_dev = label_model.predict(L=L_dev, tie_break_policy="abstain")
# results = df_dev.copy()
# results["predicted_label"] = preds_dev
# # your true labels column was named "label" when you merged gold_df in
# results = results[["blockNumber", "label", "predicted_label"]]
# display(results)

# %%
preds_dev = label_model.predict(
    L=L_dev,
    tie_break_policy="abstain"  # returns -1 wherever the model is uncertain
)

# %%
probs_dev = label_model.predict_proba(L=L_dev)
# probs_dev is an array of shape (n_examples, cardinality),
# e.g. [[0.1, 0.9], [0.8, 0.2], …]

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

results = df_dev.copy()
results["predicted_label"] = preds_dev

# If you want to ignore abstains:
mask = results["predicted_label"] != -1
y_true = results.loc[mask, "label"]
y_pred = results.loc[mask, "predicted_label"]

print("Accuracy:", accuracy_score(y_true, y_pred))
print("Classification Report:\n", classification_report(y_true, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))

# And to just glance at the table:
display(results[["blockNumber", "label", "predicted_label"]])
# Out:
# Accuracy: 0.5289392790971871
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.59      0.55     92831
#            1       0.55      0.47      0.51     97153
#
#     accuracy                           0.53    189984
#    macro avg       0.53      0.53      0.53    189984
# weighted avg       0.53      0.53      0.53    189984
#
# Confusion Matrix:
#  [[54803 38028]
#  [51466 45687]]
#         blockNumber  label  predicted_label
# 0          17176507      0                1
# 1          17176508      0                1
# 2          17176509      0                1
# 3          17176510      0                1
# 4          17176511      0                1
# ...             ...    ...              ...
# 189979     22244797      0                0
# 189980     22244798      0                0
# 189981     22244799      0                0
# 189982     22244800      0                0
# 189983     22244801      0                1
#
# [189984 rows x 3 columns]

# %%
import pandas as pd

results = []
for i, lf in enumerate(lfs):
    preds = L_dev[:, i]
    mask = preds != -1
    if not mask.any():
        continue
    acc = (preds[mask] == gold_arr[mask]).mean()
    cov = mask.mean()  # fraction of rows non-abstained
    results.append({
        "LF": lf.name,
        "Coverage": f"{cov:.2f}",
        "Accuracy": f"{acc:.2f}",
        "Votes": mask.sum(),
    })

print(pd.DataFrame(results).sort_values("Accuracy", ascending=False))
# Out:
#                    LF Coverage Accuracy   Votes
# 1    lf_base_fee_jump     0.51     0.50   96526
# 3      lf_whale_value     1.00     0.50  189984
# 4          lf_tx_fees     0.54     0.50  101882
# 5   lf_fee_dispersion     0.52     0.50   99532
# 2  lf_gas_utilisation     0.64     0.49  122184
# 0         lf_tx_count     0.91     0.48  172620

# %%
label_model.predict(L=L_train, tie_break_policy="abstain")
# 2) Mask out any abstains
mask = preds != -1
preds_masked = preds[mask]
gold_masked  = Y_dev[mask]

# 3) Compute accuracy
acc = accuracy_score(gold_masked, preds_masked)
print(f"LabelModel accuracy = {acc:.2%}")

# 4) Print confusion matrix
print("Confusion matrix:")
print(confusion_matrix(gold_masked, preds_masked))

# 5) Full classification report
print("\nClassification report:")
print(classification_report(gold_masked, preds_masked))

# %%
preds_full = label_model.predict(L=L_train, tie_break_policy="abstain")

# mask_full = df_train["blockNumber"].isin(gold_df["blockNumber"])
# preds_gold = preds_full[mask_full]
# gold_gold  = df_train.loc[mask_full, "blockNumber"].map(
#     gold_df.set_index("blockNumber")["label"]
# ).to_numpy()

# %%
print(preds_full)
# Out:
# [0 0 0 ... 1 1 1]

# %%
from snorkel.labeling import PandasLFApplier

lfs = [
    lf_tx_count, lf_size, lf_fee_dispersion, lf_tx_fees,
    lf_whale_value, lf_gas_utilisation, lf_base_fee_jump_delta
]

# 2) Build the labeling matrix over your full merged table
applier = PandasLFApplier(lfs)
L_full = applier.apply(merged)  # shape: (n_rows, n_LFs)

# 3) Predict weak labels for every row
preds_full = label_model.predict(
    L=L_full,
    tie_break_policy="abstain"    # yields -1 where the model abstains
)

# 4) Add them back to your DataFrame
merged["weak_label"] = preds_full

# Quick sanity checks:
print("Label distribution:\n", merged["weak_label"].value_counts(dropna=False))
display(merged.head())

# %%
pip install duckdb
# Out:
# Collecting duckdb
#   Downloading duckdb-1.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.0 kB)
# Downloading duckdb-1.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.7 MB/s eta 0:00:00
# Installing collected packages: duckdb
# Successfully installed duckdb-1.3.0

# %%
import duckdb
db_path = '/content/drive/MyDrive/eth1.duckdb'
conn = duckdb.connect(database=db_path, read_only=False)

# %%
conn.execute("show tables").fetch_df()
# Out:
#                    name
# 0  block_price_combined
# 1               blocks_
# 2      blocks_daily_agg
# 3             eth_price
# 4                merged
# 5         transactions_
# 6          tx_daily_agg

# %%
conn.register("merged_", merged)

conn.execute(
    """
    CREATE OR REPLACE TABLE merged AS
    SELECT *
    FROM merged_;
    """
)


df_merged = conn.execute("SELECT * FROM merged").fetchdf()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
df_merged = conn.execute("SELECT * FROM merged").fetchdf()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
df_merged.head()
# Out:
#    blockNumber   timestamp   size  transactionCount  internalTxCntSimple  \
# 0     17000000  1680911891  52739               102                   61
# 1     17000001  1680911903  66580               116                   41
# 2     17000002  1680911915  52783                61                  206
# 3     17000003  1680911927  64651               118                   42
# 4     17000004  1680911939  42665                97                   40
#
#    internalTxCntAdvanced  erc20TxCnt  erc721TxCnt  \
# 0                    411          93           19
# 1                    353          84           10
# 2                   1298          78           12
# 3                    400          92           11
# 4                    220          46           21
#
#                                  minerAddress  \
# 0  0x690b9a9e9aa1c9db991c7721a92d351db4fac990
# 1  0xbaf6dc2e647aeb6f510f9e318856a1bcd66c5e19
# 2  0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97
# 3  0x602b2c72a89a1c80dba2198c9dc472012c733e89
# 4  0x1f9090aae28b8a3dceadf281b0f12828e676c326
#
#                                           minerExtra  ...         High  \
# 0                   0x627920406275696c64657230783639  ...  1882.299194
# 1  0x4d616465206f6e20746865206d6f6f6e20627920426c...  ...  1882.299194
# 2                                       0x546974616e  ...  1882.299194
# 3                     0x6279206275696c64657230783639  ...  1882.299194
# 4               0x7273796e632d6275696c6465722e78797a  ...  1882.299194
#
#            Low        Close    Adj Close      Volume    cv_gas  delta_tx  \
# 0  1845.993896  1865.636108  1865.636108  8356130492  7.038659       NaN
# 1  1845.993896  1865.636108  1865.636108  8356130492  7.038659  0.137255
# 2  1845.993896  1865.636108  1865.636108  8356130492  7.038659 -0.474138
# 3  1845.993896  1865.636108  1865.636108  8356130492  7.038659  0.934426
# 4  1845.993896  1865.636108  1865.636108  8356130492  7.038659 -0.177966
#
#   dispersion delta_baseFee weak_label
# 0   6.943843           NaN          0
# 1   3.950088     -0.048660          0
# 2   1.553086     -0.046757          1
# 3   0.943719      0.124948          1
# 4   1.136636     -0.030474          0
#
# [5 rows x 31 columns]

# %%
conn.close()
